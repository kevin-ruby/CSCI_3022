# %% [markdown]
# <a id='top'></a>
#
# # CSCI 3022: Intro to Data Science - Fall 2019 Practicum 2
# ***
#
# This practicum is due on Canvas by **11:59 PM on Wednesday December 11**. Your solutions to theoretical questions should be done in Markdown/MathJax directly below the associated question.  Your solutions to computational questions should include any specified Python code and results as well as written commentary on your conclusions.
#
# **Here are the rules:**
#
# 1. All work, code and analysis, must be your own.
# 1. You may use your course notes, posted lecture slides, textbooks, in-class notebooks, and homework solutions as resources.  You may also search online for answers to general knowledge questions like the form of a probability distribution function or how to perform a particular operation in Python/Pandas.
# 1. This is meant to be like a coding portion of your midterm exam. So, the instructional team will be much less helpful than we typically are with homework. For example, we will not check answers, help debug your code, and so on.
# 1. If something is left open-ended, it is because we want to see how you approach the kinds of problems you will encounter in the wild, where it will not always be clear what sort of tests/methods should be applied. Feel free to ask clarifying questions though.
# 2. You may **NOT** post to message boards or other online resources asking for help.
# 3. You may **NOT** copy-paste solutions *from anywhere*.
# 4. You may **NOT** collaborate with classmates or anyone else.
# 5. In short, **your work must be your own**. It really is that simple.
#
# Violation of the above rules will result in an immediate academic sanction (*at the very least*, you will receive a 0 on this practicum or an F in the course, depending on severity), and a trip to the Honor Code Council.
#
# **By submitting this assignment, you agree to abide by the rules given above.**
#
# ***
#
# **Name**: Kevin Ruby
#
# ***
#
#
# **NOTES**:
#
# - You may not use late days on the practicums nor can you drop your practicum grades.
# - If you have a question for us, post it as a **PRIVATE** message on Piazza.  If we decide that the question is appropriate for the entire class, then we will add it to a Practicum clarifications thread.
# - Do **NOT** load or use any Python packages that are not available in Anaconda 3.6.
# - Some problems with code may be autograded.  If we provide a function API **do not** change it.  If we do not provide a function API then you're free to structure your code however you like.
# - Submit only this Jupyter notebook to Canvas.  Do not compress it using tar, rar, zip, etc.
# - This should go without saying, but... For any question that asks you to calculate something, you **must show all work to receive credit**. Sparse or nonexistent work will receive sparse or nonexistent credit.
#
# ---
# **Shortcuts:**  [Problem 1](#p1) | [Problem 2](#p2) | [Bottom](#bot)
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from calendar import month_name, different_locale
from scipy import stats
import statsmodels.api as sm
from scipy.special import binom

# %% [markdown]
# <br>
#
# ---
# <a id='p1'></a>
# [Back to top](#top)
#
# ### [40 points] Problem 1:  Amazon Forest Fires
#
# A non-profit orgranization is trying to protect the Amazon rain forest and has recruited you as their head data scientist. For your first task, they've given you a dataset with the number of fires in each state in the Amazon region during each month between 1998 and 2017. They would like to have a 95% confidence interval for the true median number of forest fires that occur in each state on a yearly basis.

# %%
#Starter Code
df = pd.read_csv('amazon.csv', thousands='.', decimal ='/', engine='python')
df.head()
# Out:
#    year state    month  number        date
# 0  1998  Acre  Janeiro     0.0  1998-01-01
# 1  1999  Acre  Janeiro     0.0  1999-01-01
# 2  2000  Acre  Janeiro     0.0  2000-01-01
# 3  2001  Acre  Janeiro     0.0  2001-01-01
# 4  2002  Acre  Janeiro     0.0  2002-01-01

# %% [markdown]
# **Part A:**  This dataset isn't paticularly useful in it's current state, so we'll need to clean it up a bit. Some data scientists say that most of their job is to wrangle data, so this will give you a taste of cleaning a real world data set. Perform the following tasks:
# 1. Drop the 'date' column. The only information this column holds is the year, which we already have in another column.
# 2. Drop any rows with null values in any of the remaining columns
# 3. Print all the unique values of the 'month' column. You'll notice that one is encoded with a differant character encoding then the format that pandas is using.
# 3. Convert the Portugese month names to English month names. We've included the 'month_name' and the 'different_encoding' modules of the python calendar library in the top cell above, if you would like to use them. There are many ways to accomplish this task, and these modules are not required, but may make things easier. As part of this step, you should make sure that the Portugese month with the encoding problem is translated to the correct English month.
# 4. Check the number column for any values that seem impossible. Drop any negative or fractional values, or any values over 50,000. 50,000 is large enough that no Brazilian state would ever have that many forest fires in one month, so we should get rid of anything above 50000.
# 5. Since you're new on the job, some of your co-workers may have played a prank on you... Print out all the unique values of the 'year' column and drop any rows with values that don't make sense.
# 6. Find the total number of rows remaining after you've done all of the above and write it out in a markdown cell. if you have correctly performed all of the tasks above, your dataframe should now have 6438 rows.
#
# **NOTE:** Since some of these tasks are not totally trivial, you may use any resources other than your classmates on this part of this problem. This means you may consult google, stack overflow, the python/pandas documentation, some random book on pandas you might have, etc... But you may not consult your classmates for help. ***CITE ALL RESOURCES USED IN A CODE COMMENT. A URL OR A BOOK TITLE IS SUFFICIENT. ANY CODE OBIVOUSLY COPIED FROM OUTSIDE SOURCES WITH OUT A CITATION WILL EARN YOU NO CREDIT ON THIS PROBLEM. YOU ARE ALLOWED TO USE THESE RESOURCES ONLY ON THIS PART OF THIS PROBLEM!***

# %%
del df['date']
df = df.dropna()
dfUnique = df.month.unique()
df['month'] = df['month'].replace(['Janeiro'], 'January')
df['month'] = df['month'].replace(['Fevereiro'], 'Feburary')
df['month'] = df['month'].replace(['Mar�o'], 'March')
df['month'] = df['month'].replace(['Abril'], 'April')
df['month'] = df['month'].replace(['Maio'], 'May')
df['month'] = df['month'].replace(['Junho'], 'June')
df['month'] = df['month'].replace(['Julho'], 'July')
df['month'] = df['month'].replace(['Agosto'], 'August')
df['month'] = df['month'].replace(['Setembro'], 'September')
df['month'] = df['month'].replace(['Outubro'], 'October')
df['month'] = df['month'].replace(['Novembro'], 'November')
df['month'] = df['month'].replace(['Dezembro'], 'December')

df = df[df['number'] >=0] 
df = df[df['number'] < 50000]


# very highly questionable, but gets the job done
df = df[df['number'] != 20.8]
df = df[df['number'] != 3454.1]
########

df = df[df['year'] != '1000bc'] 
df = df[df['year'] != '-40']
df = df[df['year'] != '10bc']
df = df[df['year'] != "our new data scientist won't notice this"]
yearuni = df.year.unique()
df.shape
# Out:
# (6438, 4)

# %% [markdown]
# **Part B:** Extract the median number of forest fires per month, yearly, by state. Store these median values in the given python dictionary.
#
# For Example:
#
# If one year of one state had the following numbers of fires:
#
# Jan: 1
#
# Feb: 2
#
# Mar: 3
#
# Apr: 4
#
# May: 5
#
# Jun: 6
#
# Jul: 7
#
# Aug: 8
#
# Sep: 9
#
# Oct: 10
#
# Nov: 11
#
# Dec: 12
#
# Then the median number of forest fires per month would be 6.5 (the average of the two middle elements since this has an even length)
#
# If the state of "test" had 5 years of recorded data, with the following median forest fire values: \[1, 2, 7, 9, 3\],  then python dictionary should look like:
#
# \{
#
#     "test": [1, 2, 7, 9, 3]
#
# \}
#
# Below we've given you one of the states values in a test, so you can ensure you are calculating the medians correctly.

# %%
#GIVEN DICTIONARY CODE
median_num_fires_monthly_yearly = {
    'Acre': None,
    'Alagoas': None,
    'Amapa': None,
    'Amazonas': None,
    'Bahia': None,
    'Ceara': None,
    'Distrito Federal': None,
    'Espirito Santo': None,
    'Goias': None,
    'Maranhao': None,
    'Mato Grosso': None,
    'Minas Gerais': None,
    'Para': None,
    'Paraiba': None,
    'Pernambuco': None,
    'Piau': None,
    'Rio': None,
    'Rondonia': None,
    'Roraima': None,
    'Santa Catarina': None,
    'Sao Paulo': None,
    'Sergipe': None,
    'Tocantins': None  
}

state_list = df.state.unique()
month_list = df.month.unique()
year_list = []

for yr in range(1998,2018):
    year_list.append(str(yr))

med=0
med_list =[]
num_list=[]
for state_ in state_list:
    med_list =[]
    med=0
    for year_ in year_list:
        num_list=[]
        for month_ in month_list:
            print(state_,month_,year_)
            if(month_ == "December" and year_ == "2017"):
                break
            else:
                numdf = df.loc[(df.year == year_) & (df.state == state_) & (df.month == month_)]
                if(numdf.empty == False):
                    num = numdf["number"].values[0]
                    num_list.append(num)
                    print(num)
        
        med = np.median(num_list)
        print(med)
        med_list.append(med)
        
    median_num_fires_monthly_yearly[state_] = med_list
    print(med_list)
print(median_num_fires_monthly_yearly['Acre'])
            
        
# num = numdf["number"].values[0]
#
#print(num_list)
# numdf = df.loc[(df.year == "2005") & (df.state == "Minas Gerais") & (df.month == "June")]
# numdf.head()
# Out:
# Acre January 1998
# 0.0
# Acre Feburary 1998
# 0.0
# Acre March 1998
# 0.0
# Acre April 1998
# 0.0
# Acre May 1998
# 0.0
# Acre June 1998
# 3.0
# Acre July 1998
# 37.0
# Acre August 1998
# 130.0
# Acre September 1998
# 509.0
# Acre October 1998
# 44.0
# Acre November 1998
# 0.0
# Acre December 1998
# 7.0
# 1.5
# Acre January 1999
# 0.0
# Acre Feburary 1999
# 0.0
# Acre March 1999
# 0.0
# Acre April 1999
# 0.0
# Acre May 1999
# 0.0
# Acre June 1999
# 0.0
# Acre July 1999
# 1.0
# Acre August 1999
# 63.0
# Acre September 1999
# 209.0
# Acre October 1999
# 60.0
# Acre November 1999
# 0.0
# Acre December 1999
# 0.0
# 0.0
# Acre January 2000
# 0.0
# Acre Feburary 2000
# 0.0
# Acre March 2000
# 11.0
# Acre April 2000
# 1.0
# Acre May 2000
# 1.0
# Acre June 2000
# 1.0
# Acre July 2000
# 1.0
# Acre August 2000
# 136.0
# Acre September 2000
# 265.0
# Acre October 2000
# 18.0
# Acre November 2000
# 0.0
# Acre December 2000
# 0.0
# 1.0
# Acre January 2001
# 0.0
# Acre Feburary 2001
# 0.0
# Acre March 2001
# 0.0
# Acre April 2001
# 0.0
# Acre May 2001
# 0.0
# Acre June 2001
# 1.0
# Acre July 2001
# 3.0
# Acre August 2001
# 396.0
# Acre September 2001
# 290.0
# Acre October 2001
# 137.0
# Acre November 2001
# 1.0
# Acre December 2001
# 0.0
# 0.5
# Acre January 2002
# 0.0
# Acre Feburary 2002
# 1.0
# Acre March 2002
# 0.0
# Acre April 2002
# 0.0
# Acre May 2002
# 0.0
# Acre June 2002
# 0.0
# Acre July 2002
# 39.0
# Acre August 2002
# 728.0
# Acre September 2002
# 1949.0
# Acre October 2002
# 687.0
# Acre November 2002
# 86.0
# Acre December 2002
# 1.0
# 1.0
# Acre January 2003
# 10.0
# Acre Feburary 2003
# 0.0
# Acre March 2003
# 0.0
# Acre April 2003
# 1.0
# Acre May 2003
# 6.0
# Acre June 2003
# 0.0
# Acre July 2003
# 168.0
# Acre August 2003
# 1976.0
# Acre September 2003
# 3942.0
# Acre October 2003
# 740.0
# Acre November 2003
# 15.0
# Acre December 2003
# 1.0
# 8.0
# Acre January 2004
# 0.0
# Acre Feburary 2004
# 3.0
# Acre March 2004
# 0.0
# Acre April 2004
# 2.0
# Acre May 2004
# 7.0
# Acre June 2004
# 5.0
# Acre July 2004
# 42.0
# Acre August 2004
# 645.0
# Acre September 2004
# 1978.0
# Acre October 2004
# 461.0
# Acre November 2004
# 10.0
# Acre December 2004
# 7.0
# 7.0
# Acre January 2005
# 12.0
# Acre Feburary 2005
# 0.0
# Acre March 2005
# 3.0
# Acre April 2005
# 1.0
# Acre May 2005
# 2.0
# Acre June 2005
# 27.0
# Acre July 2005
# 368.0
# Acre August 2005
# 4198.0
# Acre September 2005
# 4253.0
# Acre October 2005
# 547.0
# Acre November 2005
# 14.0
# Acre December 2005
# 2.0
# 13.0
# Acre January 2006
# 4.0
# Acre Feburary 2006
# 0.0
# Acre March 2006
# 0.0
# Acre April 2006
# 0.0
# Acre May 2006
# 8.0
# Acre June 2006
# 1.0
# Acre July 2006
# 33.0
# Acre August 2006
# 839.0
# Acre September 2006
# 2370.0
# Acre October 2006
# 316.0
# Acre November 2006
# 18.0
# Acre December 2006
# 0.0
# 6.0
# Acre January 2007
# 0.0
# Acre Feburary 2007
# 5.0
# Acre March 2007
# 2.0
# Acre April 2007
# 0.0
# Acre May 2007
# 1.0
# Acre June 2007
# 4.0
# Acre July 2007
# 29.0
# Acre August 2007
# 960.0
# Acre September 2007
# 2080.0
# Acre October 2007
# 203.0
# Acre November 2007
# 7.0
# Acre December 2007
# 0.0
# 4.5
# Acre January 2008
# 0.0
# Acre Feburary 2008
# 0.0
# Acre March 2008
# 0.0
# Acre April 2008
# 0.0
# Acre May 2008
# 0.0
# Acre June 2008
# 0.0
# Acre July 2008
# 41.0
# Acre August 2008
# 445.0
# Acre September 2008
# 1666.0
# Acre October 2008
# 652.0
# Acre November 2008
# 4.0
# Acre December 2008
# 0.0
# 0.0
# Acre January 2009
# 0.0
# Acre Feburary 2009
# 2.0
# Acre March 2009
# 1.0
# Acre April 2009
# 0.0
# Acre May 2009
# 3.0
# Acre June 2009
# 0.0
# Acre July 2009
# 31.0
# Acre August 2009
# 194.0
# Acre September 2009
# 1265.0
# Acre October 2009
# 565.0
# Acre November 2009
# 33.0
# Acre December 2009
# 1.0
# 2.5
# Acre January 2010
# 1.0
# Acre Feburary 2010
# 0.0
# Acre March 2010
# 0.0
# Acre April 2010
# 3.0
# Acre May 2010
# 9.0
# Acre June 2010
# 1.0
# Acre July 2010
# 126.0
# Acre August 2010
# 1682.0
# Acre September 2010
# 2531.0
# Acre October 2010
# 292.0
# Acre November 2010
# 39.0
# Acre December 2010
# 0.0
# 6.0
# Acre January 2011
# 0.0
# Acre Feburary 2011
# 0.0
# Acre March 2011
# 0.0
# Acre April 2011
# 2.0
# Acre May 2011
# 3.0
# Acre June 2011
# 10.0
# Acre July 2011
# 93.0
# Acre August 2011
# 425.0
# Acre September 2011
# 1204.0
# Acre October 2011
# 97.0
# Acre November 2011
# 74.0
# Acre December 2011
# 4.0
# 7.0
# Acre January 2012
# 0.0
# Acre Feburary 2012
# 0.0
# Acre March 2012
# 1.0
# Acre April 2012
# 1.0
# Acre May 2012
# 3.0
# Acre June 2012
# 7.0
# Acre July 2012
# 71.0
# Acre August 2012
# 739.0
# Acre September 2012
# 1996.0
# Acre October 2012
# 348.0
# Acre November 2012
# 13.0
# Acre December 2012
# 1.0
# 5.0
# Acre January 2013
# 0.0
# Acre Feburary 2013
# 0.0
# Acre March 2013
# 2.0
# Acre April 2013
# 19.0
# Acre May 2013
# 4.0
# Acre June 2013
# 8.0
# Acre July 2013
# 54.0
# Acre August 2013
# 679.0
# Acre September 2013
# 2136.0
# Acre October 2013
# 258.0
# Acre November 2013
# 79.0
# Acre December 2013
# 3.0
# 13.5
# Acre January 2014
# 0.0
# Acre Feburary 2014
# 0.0
# Acre March 2014
# 1.0
# Acre April 2014
# 7.0
# Acre May 2014
# 1.0
# Acre June 2014
# 17.0
# Acre July 2014
# 60.0
# Acre August 2014
# 1100.0
# Acre September 2014
# 2175.0
# Acre October 2014
# 406.0
# Acre November 2014
# 56.0
# Acre December 2014
# 6.0
# 12.0
# Acre January 2015
# 1.0
# Acre Feburary 2015
# 2.0
# Acre March 2015
# 2.0
# Acre April 2015
# 3.0
# Acre May 2015
# 2.0
# Acre June 2015
# 40.0
# Acre July 2015
# 109.0
# Acre August 2015
# 1397.0
# Acre September 2015
# 2928.0
# Acre October 2015
# 905.0
# Acre November 2015
# 115.0
# Acre December 2015
# 8.0
# 24.0
# Acre January 2016
# 12.0
# Acre Feburary 2016
# 5.0
# Acre March 2016
# 0.0
# Acre April 2016
# 0.0
# Acre May 2016
# 21.0
# Acre June 2016
# 87.0
# Acre July 2016
# 533.0
# Acre August 2016
# 2188.0
# Acre September 2016
# 3586.0
# Acre October 2016
# 509.0
# Acre November 2016
# 46.0
# Acre December 2016
# 6.0
# 33.5
# Acre January 2017
# 0.0
# Acre Feburary 2017
# 1.0
# Acre March 2017
# 0.0
# Acre April 2017
# 1.0
# Acre May 2017
# 10.0
# Acre June 2017
# 45.0
# Acre July 2017
# 457.0
# Acre August 2017
# 1493.0
# Acre September 2017
# 3429.0
# Acre October 2017
# 1508.0
# Acre November 2017
# 98.0
# Acre December 2017
# 45.0
# [1.5, 0.0, 1.0, 0.5, 1.0, 8.0, 7.0, 13.0, 6.0, 4.5, 0.0, 2.5, 6.0, 7.0, 5.0, 13.5, 12.0, 24.0, 33.5, 45.0]
# Alagoas January 1998
# 0.0
# Alagoas Feburary 1998
# 0.0
# Alagoas March 1998
# 0.0
# Alagoas April 1998
# 0.0
# Alagoas May 1998
# 0.0
# Alagoas June 1998
# 0.0
# Alagoas July 1998
# 0.0
# Alagoas August 1998
# 1.0
# Alagoas September 1998
# 14.0
# Alagoas October 1998
# 20.0
# Alagoas November 1998
# 19.0
# Alagoas December 1998
# 32.0
# 0.0
# Alagoas January 1999
# 58.0
# Alagoas Feburary 1999
# 20.0
# Alagoas March 1999
# 52.0
# Alagoas April 1999
# 4.0
# Alagoas May 1999
# 1.0
# Alagoas June 1999
# 0.0
# Alagoas July 1999
# 0.0
# Alagoas August 1999
# 3.0
# Alagoas September 1999
# 3.0
# Alagoas October 1999
# 4.0
# Alagoas November 1999
# 15.0
# Alagoas December 1999
# 12.0
# 4.0
# Alagoas January 2000
# 11.0
# Alagoas Feburary 2000
# 16.0
# Alagoas March 2000
# 32.0
# Alagoas April 2000
# 20.0
# Alagoas May 2000
# 1.0
# Alagoas June 2000
# 0.0
# Alagoas July 2000
# 0.0
# Alagoas August 2000
# 4.0
# Alagoas September 2000
# 22.0
# Alagoas October 2000
# 13.0
# Alagoas November 2000
# 2.0
# Alagoas December 2000
# 2.0
# 7.5
# Alagoas January 2001
# 5.0
# Alagoas Feburary 2001
# 4.0
# Alagoas March 2001
# 0.0
# Alagoas April 2001
# 0.0
# Alagoas May 2001
# 2.0
# Alagoas June 2001
# 2.0
# Alagoas July 2001
# 0.0
# Alagoas August 2001
# 1.0
# Alagoas September 2001
# 5.0
# Alagoas October 2001
# 15.0
# Alagoas November 2001
# 22.0
# Alagoas December 2001
# 30.0
# 3.0
# Alagoas January 2002
# 12.0
# Alagoas Feburary 2002
# 15.0
# Alagoas March 2002
# 27.0
# Alagoas April 2002
# 6.0
# Alagoas May 2002
# 1.0
# Alagoas June 2002
# 0.0
# Alagoas July 2002
# 5.0
# Alagoas August 2002
# 3.0
# Alagoas September 2002
# 14.0
# Alagoas October 2002
# 30.0
# Alagoas November 2002
# 50.0
# Alagoas December 2002
# 95.0
# 13.0
# Alagoas January 2003
# 150.0
# Alagoas Feburary 2003
# 33.0
# Alagoas March 2003
# 15.0
# Alagoas April 2003
# 20.0
# Alagoas May 2003
# 1.0
# Alagoas June 2003
# 0.0
# Alagoas July 2003
# 0.0
# Alagoas August 2003
# 2.0
# Alagoas September 2003
# 8.0
# Alagoas October 2003
# 10.0
# Alagoas November 2003
# 17.0
# Alagoas December 2003
# 43.0
# 12.5
# Alagoas January 2004
# 9.0
# Alagoas Feburary 2004
# 7.0
# Alagoas March 2004
# 16.0
# Alagoas April 2004
# 6.0
# Alagoas May 2004
# 3.0
# Alagoas June 2004
# 0.0
# Alagoas July 2004
# 0.0
# Alagoas August 2004
# 2.0
# Alagoas September 2004
# 5.0
# Alagoas October 2004
# 12.0
# Alagoas November 2004
# 28.0
# Alagoas December 2004
# 71.0
# 6.5
# Alagoas January 2005
# 83.0
# Alagoas Feburary 2005
# 31.0
# Alagoas March 2005
# 35.0
# Alagoas April 2005
# 1.0
# Alagoas May 2005
# 0.0
# Alagoas June 2005
# 0.0
# Alagoas July 2005
# 0.0
# Alagoas August 2005
# 2.0
# Alagoas September 2005
# 7.0
# Alagoas October 2005
# 17.0
# Alagoas November 2005
# 25.0
# Alagoas December 2005
# 16.0
# 11.5
# Alagoas January 2006
# 29.0
# Alagoas Feburary 2006
# 14.0
# Alagoas March 2006
# 37.0
# Alagoas April 2006
# 2.0
# Alagoas May 2006
# 0.0
# Alagoas June 2006
# 0.0
# Alagoas July 2006
# 0.0
# Alagoas August 2006
# 1.0
# Alagoas September 2006
# 4.0
# Alagoas October 2006
# 32.0
# Alagoas November 2006
# 12.0
# Alagoas December 2006
# 30.0
# 8.0
# Alagoas January 2007
# 33.0
# Alagoas Feburary 2007
# 28.0
# Alagoas March 2007
# 7.0
# Alagoas April 2007
# 1.0
# Alagoas May 2007
# 0.0
# Alagoas June 2007
# 0.0
# Alagoas July 2007
# 0.0
# Alagoas August 2007
# 3.0
# Alagoas September 2007
# 2.0
# Alagoas October 2007
# 6.0
# Alagoas November 2007
# 15.0
# Alagoas December 2007
# 33.0
# 4.5
# Alagoas January 2008
# 55.0
# Alagoas Feburary 2008
# 74.0
# Alagoas March 2008
# 31.0
# Alagoas April 2008
# 18.0
# Alagoas May 2008
# 0.0
# Alagoas June 2008
# 0.0
# Alagoas July 2008
# 0.0
# Alagoas August 2008
# 1.0
# Alagoas September 2008
# 9.0
# Alagoas October 2008
# 18.0
# Alagoas November 2008
# 37.0
# Alagoas December 2008
# 34.0
# 18.0
# Alagoas January 2009
# 104.0
# Alagoas Feburary 2009
# 32.0
# Alagoas March 2009
# 31.0
# Alagoas April 2009
# 5.0
# Alagoas May 2009
# 0.0
# Alagoas June 2009
# 0.0
# Alagoas July 2009
# 0.0
# Alagoas August 2009
# 0.0
# Alagoas September 2009
# 13.0
# Alagoas October 2009
# 30.0
# Alagoas November 2009
# 55.0
# Alagoas December 2009
# 55.0
# 21.5
# Alagoas January 2010
# 23.0
# Alagoas Feburary 2010
# 26.0
# Alagoas March 2010
# 70.0
# Alagoas April 2010
# 3.0
# Alagoas May 2010
# 0.0
# Alagoas June 2010
# 0.0
# Alagoas July 2010
# 2.0
# Alagoas August 2010
# 1.0
# Alagoas September 2010
# 5.0
# Alagoas October 2010
# 16.0
# Alagoas November 2010
# 31.0
# Alagoas December 2010
# 45.0
# 10.5
# Alagoas January 2011
# 41.0
# Alagoas Feburary 2011
# 33.0
# Alagoas March 2011
# 34.0
# Alagoas April 2011
# 17.0
# Alagoas May 2011
# 0.0
# Alagoas June 2011
# 2.0
# Alagoas July 2011
# 0.0
# Alagoas August 2011
# 4.0
# Alagoas September 2011
# 5.0
# Alagoas October 2011
# 23.0
# Alagoas November 2011
# 23.0
# Alagoas December 2011
# 50.0
# 20.0
# Alagoas January 2012
# 36.0
# Alagoas Feburary 2012
# 41.0
# Alagoas March 2012
# 44.0
# Alagoas April 2012
# 18.0
# Alagoas May 2012
# 21.0
# Alagoas June 2012
# 4.0
# Alagoas July 2012
# 0.0
# Alagoas August 2012
# 0.0
# Alagoas September 2012
# 6.0
# Alagoas October 2012
# 28.0
# Alagoas November 2012
# 95.0
# Alagoas December 2012
# 59.0
# 24.5
# Alagoas January 2013
# 49.0
# Alagoas Feburary 2013
# 19.0
# Alagoas March 2013
# 31.0
# Alagoas April 2013
# 25.0
# Alagoas May 2013
# 2.0
# Alagoas June 2013
# 1.0
# Alagoas July 2013
# 0.0
# Alagoas August 2013
# 0.0
# Alagoas September 2013
# 4.0
# Alagoas October 2013
# 25.0
# Alagoas November 2013
# 10.0
# Alagoas December 2013
# 42.0
# 14.5
# Alagoas January 2014
# 54.0
# Alagoas Feburary 2014
# 29.0
# Alagoas March 2014
# 28.0
# Alagoas April 2014
# 16.0
# Alagoas May 2014
# 1.0
# Alagoas June 2014
# 2.0
# Alagoas July 2014
# 1.0
# Alagoas August 2014
# 3.0
# Alagoas September 2014
# 11.0
# Alagoas October 2014
# 7.0
# Alagoas November 2014
# 14.0
# Alagoas December 2014
# 24.0
# 12.5
# Alagoas January 2015
# 81.0
# Alagoas Feburary 2015
# 46.0
# Alagoas March 2015
# 32.0
# Alagoas April 2015
# 63.0
# Alagoas May 2015
# 18.0
# Alagoas June 2015
# 2.0
# Alagoas July 2015
# 0.0
# Alagoas August 2015
# 3.0
# Alagoas September 2015
# 7.0
# Alagoas October 2015
# 40.0
# Alagoas November 2015
# 162.0
# Alagoas December 2015
# 136.0
# 36.0
# Alagoas January 2016
# 24.0
# Alagoas Feburary 2016
# 14.0
# Alagoas March 2016
# 9.0
# Alagoas April 2016
# 13.0
# Alagoas May 2016
# 4.0
# Alagoas June 2016
# 5.0
# Alagoas July 2016
# 3.0
# Alagoas August 2016
# 5.0
# Alagoas September 2016
# 18.0
# Alagoas October 2016
# 74.0
# Alagoas November 2016
# 76.0
# Alagoas December 2016
# 155.0
# 13.5
# Alagoas January 2017
# 38.0
# Alagoas Feburary 2017
# 21.0
# Alagoas March 2017
# 23.0
# Alagoas April 2017
# 7.0
# Alagoas May 2017
# 1.0
# Alagoas June 2017
# 2.0
# Alagoas July 2017
# 0.0
# Alagoas August 2017
# 1.0
# Alagoas September 2017
# 4.0
# Alagoas October 2017
# 14.0
# Alagoas November 2017
# 10.0
# Alagoas December 2017
# 7.0
# [0.0, 4.0, 7.5, 3.0, 13.0, 12.5, 6.5, 11.5, 8.0, 4.5, 18.0, 21.5, 10.5, 20.0, 24.5, 14.5, 12.5, 36.0, 13.5, 7.0]
# Amapa January 1998
# 0.0
# Amapa Feburary 1998
# 0.0
# Amapa March 1998
# 0.0
# Amapa April 1998
# 0.0
# Amapa May 1998
# 0.0
# Amapa June 1998
# 0.0
# Amapa July 1998
# 0.0
# Amapa August 1998
# 1.0
# Amapa September 1998
# 20.0
# Amapa October 1998
# 42.0
# Amapa November 1998
# 131.0
# Amapa December 1998
# 84.0
# 0.0
# Amapa January 1999
# 0.0
# Amapa Feburary 1999
# 1.0
# Amapa March 1999
# 2.0
# Amapa April 1999
# 0.0
# Amapa May 1999
# 0.0
# Amapa June 1999
# 2.0
# Amapa July 1999
# 0.0
# Amapa August 1999
# 0.0
# Amapa September 1999
# 4.0
# Amapa October 1999
# 25.0
# Amapa November 1999
# 26.0
# Amapa December 1999
# 41.0
# 1.5
# Amapa January 2000
# 2.0
# Amapa Feburary 2000
# 0.0
# Amapa March 2000
# 0.0
# Amapa April 2000
# 0.0
# Amapa May 2000
# 0.0
# Amapa June 2000
# 0.0
# Amapa July 2000
# 0.0
# Amapa August 2000
# 3.0
# Amapa September 2000
# 19.0
# Amapa October 2000
# 42.0
# Amapa November 2000
# 157.0
# Amapa December 2000
# 30.0
# 1.0
# Amapa January 2001
# 0.0
# Amapa Feburary 2001
# 0.0
# Amapa March 2001
# 0.0
# Amapa April 2001
# 0.0
# Amapa May 2001
# 0.0
# Amapa June 2001
# 0.0
# Amapa July 2001
# 1.0
# Amapa August 2001
# 12.0
# Amapa September 2001
# 95.0
# Amapa October 2001
# 194.0
# Amapa November 2001
# 406.0
# Amapa December 2001
# 593.0
# 0.5
# Amapa January 2002
# 7.0
# Amapa Feburary 2002
# 2.0
# Amapa March 2002
# 0.0
# Amapa April 2002
# 0.0
# Amapa May 2002
# 3.0
# Amapa June 2002
# 0.0
# Amapa July 2002
# 1.0
# Amapa August 2002
# 18.0
# Amapa September 2002
# 73.0
# Amapa October 2002
# 557.0
# Amapa November 2002
# 1096.0
# Amapa December 2002
# 200.0
# 5.0
# Amapa January 2003
# 31.0
# Amapa Feburary 2003
# 0.0
# Amapa March 2003
# 1.0
# Amapa April 2003
# 2.0
# Amapa May 2003
# 0.0
# Amapa June 2003
# 0.0
# Amapa July 2003
# 0.0
# Amapa August 2003
# 14.0
# Amapa September 2003
# 88.0
# Amapa October 2003
# 355.0
# Amapa November 2003
# 750.0
# Amapa December 2003
# 411.0
# 8.0
# Amapa January 2004
# 38.0
# Amapa Feburary 2004
# 2.0
# Amapa March 2004
# 0.0
# Amapa April 2004
# 0.0
# Amapa May 2004
# 0.0
# Amapa June 2004
# 5.0
# Amapa July 2004
# 2.0
# Amapa August 2004
# 9.0
# Amapa September 2004
# 67.0
# Amapa October 2004
# 412.0
# Amapa November 2004
# 949.0
# Amapa December 2004
# 777.0
# 7.0
# Amapa January 2005
# 109.0
# Amapa Feburary 2005
# 1.0
# Amapa March 2005
# 0.0
# Amapa April 2005
# 0.0
# Amapa May 2005
# 0.0
# Amapa June 2005
# 2.0
# Amapa July 2005
# 0.0
# Amapa August 2005
# 4.0
# Amapa September 2005
# 97.0
# Amapa October 2005
# 335.0
# Amapa November 2005
# 685.0
# Amapa December 2005
# 38.0
# 3.0
# Amapa January 2006
# 6.0
# Amapa Feburary 2006
# 2.0
# Amapa March 2006
# 0.0
# Amapa April 2006
# 0.0
# Amapa May 2006
# 0.0
# Amapa June 2006
# 0.0
# Amapa July 2006
# 0.0
# Amapa August 2006
# 11.0
# Amapa September 2006
# 112.0
# Amapa October 2006
# 405.0
# Amapa November 2006
# 207.0
# Amapa December 2006
# 74.0
# 4.0
# Amapa January 2007
# 0.0
# Amapa Feburary 2007
# 0.0
# Amapa March 2007
# 0.0
# Amapa April 2007
# 0.0
# Amapa May 2007
# 0.0
# Amapa June 2007
# 0.0
# Amapa July 2007
# 0.0
# Amapa August 2007
# 5.0
# Amapa September 2007
# 61.0
# Amapa October 2007
# 162.0
# Amapa November 2007
# 198.0
# Amapa December 2007
# 14.0
# 0.0
# Amapa January 2008
# 2.0
# Amapa Feburary 2008
# 0.0
# Amapa March 2008
# 1.0
# Amapa April 2008
# 2.0
# Amapa May 2008
# 0.0
# Amapa June 2008
# 0.0
# Amapa July 2008
# 0.0
# Amapa August 2008
# 4.0
# Amapa September 2008
# 83.0
# Amapa October 2008
# 395.0
# Amapa November 2008
# 266.0
# Amapa December 2008
# 32.0
# 2.0
# Amapa January 2009
# 4.0
# Amapa Feburary 2009
# 0.0
# Amapa March 2009
# 1.0
# Amapa April 2009
# 0.0
# Amapa May 2009
# 2.0
# Amapa June 2009
# 1.0
# Amapa July 2009
# 4.0
# Amapa August 2009
# 20.0
# Amapa September 2009
# 188.0
# Amapa October 2009
# 765.0
# Amapa November 2009
# 1019.0
# Amapa December 2009
# 123.0
# 4.0
# Amapa January 2010
# 2.0
# Amapa Feburary 2010
# 0.0
# Amapa March 2010
# 2.0
# Amapa April 2010
# 2.0
# Amapa May 2010
# 2.0
# Amapa June 2010
# 0.0
# Amapa July 2010
# 2.0
# Amapa August 2010
# 1.0
# Amapa September 2010
# 63.0
# Amapa October 2010
# 265.0
# Amapa November 2010
# 339.0
# Amapa December 2010
# 43.0
# 2.0
# Amapa January 2011
# 0.0
# Amapa Feburary 2011
# 3.0
# Amapa March 2011
# 0.0
# Amapa April 2011
# 0.0
# Amapa May 2011
# 2.0
# Amapa June 2011
# 0.0
# Amapa July 2011
# 5.0
# Amapa August 2011
# 16.0
# Amapa September 2011
# 128.0
# Amapa October 2011
# 304.0
# Amapa November 2011
# 282.0
# Amapa December 2011
# 360.0
# 4.0
# Amapa January 2012
# 30.0
# Amapa Feburary 2012
# 5.0
# Amapa March 2012
# 1.0
# Amapa April 2012
# 2.0
# Amapa May 2012
# 2.0
# Amapa June 2012
# 7.0
# Amapa July 2012
# 3.0
# Amapa August 2012
# 19.0
# Amapa September 2012
# 168.0
# Amapa October 2012
# 475.0
# Amapa November 2012
# 969.0
# Amapa December 2012
# 422.0
# 13.0
# Amapa January 2013
# 3.0
# Amapa Feburary 2013
# 0.0
# Amapa March 2013
# 0.0
# Amapa April 2013
# 2.0
# Amapa May 2013
# 0.0
# Amapa June 2013
# 1.0
# Amapa July 2013
# 1.0
# Amapa August 2013
# 9.0
# Amapa September 2013
# 85.0
# Amapa October 2013
# 385.0
# Amapa November 2013
# 341.0
# Amapa December 2013
# 148.0
# 2.5
# Amapa January 2014
# 10.0
# Amapa Feburary 2014
# 2.0
# Amapa March 2014
# 1.0
# Amapa April 2014
# 0.0
# Amapa May 2014
# 0.0
# Amapa June 2014
# 0.0
# Amapa July 2014
# 4.0
# Amapa August 2014
# 18.0
# Amapa September 2014
# 137.0
# Amapa October 2014
# 480.0
# Amapa November 2014
# 484.0
# Amapa December 2014
# 354.0
# 7.0
# Amapa January 2015
# 14.0
# Amapa Feburary 2015
# 1.0
# Amapa March 2015
# 2.0
# Amapa April 2015
# 0.0
# Amapa May 2015
# 0.0
# Amapa June 2015
# 3.0
# Amapa July 2015
# 5.0
# Amapa August 2015
# 40.0
# Amapa September 2015
# 192.0
# Amapa October 2015
# 827.0
# Amapa November 2015
# 1300.0
# Amapa December 2015
# 269.0
# 9.5
# Amapa January 2016
# 19.0
# Amapa Feburary 2016
# 1.0
# Amapa March 2016
# 5.0
# Amapa April 2016
# 0.0
# Amapa May 2016
# 1.0
# Amapa June 2016
# 2.0
# Amapa July 2016
# 1.0
# Amapa August 2016
# 37.0
# Amapa September 2016
# 142.0
# Amapa October 2016
# 793.0
# Amapa November 2016
# 1161.0
# Amapa December 2016
# 491.0
# 12.0
# Amapa January 2017
# 2.0
# Amapa Feburary 2017
# 0.0
# Amapa March 2017
# 0.0
# Amapa April 2017
# 3.0
# Amapa May 2017
# 1.0
# Amapa June 2017
# 2.0
# Amapa July 2017
# 3.0
# Amapa August 2017
# 33.0
# Amapa September 2017
# 95.0
# Amapa October 2017
# 468.0
# Amapa November 2017
# 858.0
# Amapa December 2017
# 3.0
# [0.0, 1.5, 1.0, 0.5, 5.0, 8.0, 7.0, 3.0, 4.0, 0.0, 2.0, 4.0, 2.0, 4.0, 13.0, 2.5, 7.0, 9.5, 12.0, 3.0]
# Amazonas January 1998
# 0.0
# Amazonas Feburary 1998
# 0.0
# Amazonas March 1998
# 0.0
# Amazonas April 1998
# 0.0
# Amazonas May 1998
# 0.0
# Amazonas June 1998
# 2.0
# Amazonas July 1998
# 71.0
# Amazonas August 1998
# 321.0
# Amazonas September 1998
# 267.0
# Amazonas October 1998
# 83.0
# Amazonas November 1998
# 6.0
# Amazonas December 1998
# 196.0
# 4.0
# Amazonas January 1999
# 3.0
# Amazonas Feburary 1999
# 43.0
# Amazonas March 1999
# 7.0
# Amazonas April 1999
# 2.0
# Amazonas May 1999
# 0.0
# Amazonas June 1999
# 7.0
# Amazonas July 1999
# 11.0
# Amazonas August 1999
# 259.0
# Amazonas September 1999
# 216.0
# Amazonas October 1999
# 479.0
# Amazonas November 1999
# 32.0
# Amazonas December 1999
# 2.0
# 9.0
# Amazonas January 2000
# 7.0
# Amazonas Feburary 2000
# 62.0
# Amazonas March 2000
# 69.0
# Amazonas April 2000
# 18.0
# Amazonas May 2000
# 51.0
# Amazonas June 2000
# 6.0
# Amazonas July 2000
# 39.0
# Amazonas August 2000
# 180.0
# Amazonas September 2000
# 189.0
# Amazonas October 2000
# 145.0
# Amazonas November 2000
# 27.0
# Amazonas December 2000
# 60.0
# 55.5
# Amazonas January 2001
# 3.0
# Amazonas Feburary 2001
# 8.0
# Amazonas March 2001
# 6.0
# Amazonas April 2001
# 1.0
# Amazonas May 2001
# 0.0
# Amazonas June 2001
# 5.0
# Amazonas July 2001
# 9.0
# Amazonas August 2001
# 501.0
# Amazonas September 2001
# 166.0
# Amazonas October 2001
# 332.0
# Amazonas November 2001
# 244.0
# Amazonas December 2001
# 22.0
# 8.5
# Amazonas January 2002
# 17.0
# Amazonas Feburary 2002
# 2.0
# Amazonas March 2002
# 5.0
# Amazonas April 2002
# 2.0
# Amazonas May 2002
# 8.0
# Amazonas June 2002
# 5.0
# Amazonas July 2002
# 146.0
# Amazonas August 2002
# 741.0
# Amazonas September 2002
# 928.0
# Amazonas October 2002
# 695.0
# Amazonas November 2002
# 259.0
# Amazonas December 2002
# 44.0
# 30.5
# Amazonas January 2003
# 158.0
# Amazonas Feburary 2003
# 62.0
# Amazonas March 2003
# 64.0
# Amazonas April 2003
# 11.0
# Amazonas May 2003
# 2.0
# Amazonas June 2003
# 3.0
# Amazonas July 2003
# 180.0
# Amazonas August 2003
# 1867.0
# Amazonas September 2003
# 1401.0
# Amazonas October 2003
# 725.0
# Amazonas November 2003
# 169.0
# Amazonas December 2003
# 147.0
# 152.5
# Amazonas January 2004
# 123.0
# Amazonas Feburary 2004
# 92.0
# Amazonas March 2004
# 6.0
# Amazonas April 2004
# 4.0
# Amazonas May 2004
# 0.0
# Amazonas June 2004
# 12.0
# Amazonas July 2004
# 177.0
# Amazonas August 2004
# 1207.0
# Amazonas September 2004
# 911.0
# Amazonas October 2004
# 710.0
# Amazonas November 2004
# 209.0
# Amazonas December 2004
# 53.0
# 107.5
# Amazonas January 2005
# 44.0
# Amazonas Feburary 2005
# 6.0
# Amazonas March 2005
# 12.0
# Amazonas April 2005
# 5.0
# Amazonas May 2005
# 8.0
# Amazonas June 2005
# 78.0
# Amazonas July 2005
# 676.0
# Amazonas August 2005
# 2316.0
# Amazonas September 2005
# 2812.0
# Amazonas October 2005
# 545.0
# Amazonas November 2005
# 261.0
# Amazonas December 2005
# 17.0
# 61.0
# Amazonas January 2006
# 20.0
# Amazonas Feburary 2006
# 10.0
# Amazonas March 2006
# 20.0
# Amazonas April 2006
# 5.0
# Amazonas May 2006
# 4.0
# Amazonas June 2006
# 9.0
# Amazonas July 2006
# 123.0
# Amazonas August 2006
# 1422.0
# Amazonas September 2006
# 2218.0
# Amazonas October 2006
# 721.0
# Amazonas November 2006
# 59.0
# Amazonas December 2006
# 23.0
# 21.5
# Amazonas January 2007
# 37.0
# Amazonas Feburary 2007
# 92.0
# Amazonas March 2007
# 6.0
# Amazonas April 2007
# 0.0
# Amazonas May 2007
# 0.0
# Amazonas June 2007
# 23.0
# Amazonas July 2007
# 116.0
# Amazonas August 2007
# 2241.0
# Amazonas September 2007
# 1360.0
# Amazonas October 2007
# 215.0
# Amazonas November 2007
# 90.0
# Amazonas December 2007
# 7.0
# 63.5
# Amazonas January 2008
# 16.0
# Amazonas Feburary 2008
# 32.0
# Amazonas March 2008
# 10.0
# Amazonas April 2008
# 13.0
# Amazonas May 2008
# 1.0
# Amazonas June 2008
# 7.0
# Amazonas July 2008
# 108.0
# Amazonas August 2008
# 861.0
# Amazonas September 2008
# 998.0
# Amazonas October 2008
# 632.0
# Amazonas November 2008
# 39.0
# Amazonas December 2008
# 0.0
# 24.0
# Amazonas January 2009
# 9.0
# Amazonas Feburary 2009
# 3.0
# Amazonas March 2009
# 11.0
# Amazonas April 2009
# 1.0
# Amazonas May 2009
# 3.0
# Amazonas June 2009
# 13.0
# Amazonas July 2009
# 199.0
# Amazonas August 2009
# 1321.0
# Amazonas September 2009
# 3091.0
# Amazonas October 2009
# 2189.0
# Amazonas November 2009
# 973.0
# Amazonas December 2009
# 102.0
# 57.5
# Amazonas January 2010
# 82.0
# Amazonas Feburary 2010
# 81.0
# Amazonas March 2010
# 116.0
# Amazonas April 2010
# 11.0
# Amazonas May 2010
# 13.0
# Amazonas June 2010
# 9.0
# Amazonas July 2010
# 640.0
# Amazonas August 2010
# 3727.0
# Amazonas September 2010
# 2781.0
# Amazonas October 2010
# 889.0
# Amazonas November 2010
# 354.0
# Amazonas December 2010
# 123.0
# 119.5
# Amazonas January 2011
# 53.0
# Amazonas Feburary 2011
# 30.0
# Amazonas March 2011
# 49.0
# Amazonas April 2011
# 5.0
# Amazonas May 2011
# 6.0
# Amazonas June 2011
# 22.0
# Amazonas July 2011
# 271.0
# Amazonas August 2011
# 1243.0
# Amazonas September 2011
# 1295.0
# Amazonas October 2011
# 694.0
# Amazonas November 2011
# 399.0
# Amazonas December 2011
# 121.0
# 87.0
# Amazonas January 2012
# 6.0
# Amazonas Feburary 2012
# 25.0
# Amazonas March 2012
# 17.0
# Amazonas April 2012
# 3.0
# Amazonas May 2012
# 12.0
# Amazonas June 2012
# 45.0
# Amazonas July 2012
# 234.0
# Amazonas August 2012
# 3011.0
# Amazonas September 2012
# 2392.0
# Amazonas October 2012
# 1238.0
# Amazonas November 2012
# 682.0
# Amazonas December 2012
# 80.0
# 62.5
# Amazonas January 2013
# 37.0
# Amazonas Feburary 2013
# 16.0
# Amazonas March 2013
# 49.0
# Amazonas April 2013
# 20.0
# Amazonas May 2013
# 19.0
# Amazonas June 2013
# 56.0
# Amazonas July 2013
# 248.0
# Amazonas August 2013
# 1276.0
# Amazonas September 2013
# 1739.0
# Amazonas October 2013
# 1202.0
# Amazonas November 2013
# 220.0
# Amazonas December 2013
# 236.0
# 138.0
# Amazonas January 2014
# 46.0
# Amazonas Feburary 2014
# 49.0
# Amazonas March 2014
# 50.0
# Amazonas April 2014
# 25.0
# Amazonas May 2014
# 12.0
# Amazonas June 2014
# 74.0
# Amazonas July 2014
# 202.0
# Amazonas August 2014
# 3852.0
# Amazonas September 2014
# 3057.0
# Amazonas October 2014
# 952.0
# Amazonas November 2014
# 676.0
# Amazonas December 2014
# 293.0
# 138.0
# Amazonas January 2015
# 35.0
# Amazonas Feburary 2015
# 107.0
# Amazonas March 2015
# 46.0
# Amazonas April 2015
# 24.0
# Amazonas May 2015
# 10.0
# Amazonas June 2015
# 33.0
# Amazonas July 2015
# 356.0
# Amazonas August 2015
# 4564.0
# Amazonas September 2015
# 5882.0
# Amazonas October 2015
# 2494.0
# Amazonas November 2015
# 1054.0
# Amazonas December 2015
# 565.0
# 231.5
# Amazonas January 2016
# 770.0
# Amazonas Feburary 2016
# 275.0
# Amazonas March 2016
# 140.0
# Amazonas April 2016
# 22.0
# Amazonas May 2016
# 30.0
# Amazonas June 2016
# 90.0
# Amazonas July 2016
# 1137.0
# Amazonas August 2016
# 3611.0
# Amazonas September 2016
# 3119.0
# Amazonas October 2016
# 2105.0
# Amazonas November 2016
# 591.0
# Amazonas December 2016
# 133.0
# 433.0
# Amazonas January 2017
# 65.0
# Amazonas Feburary 2017
# 52.0
# Amazonas March 2017
# 45.0
# Amazonas April 2017
# 20.0
# Amazonas May 2017
# 40.0
# Amazonas June 2017
# 119.0
# Amazonas July 2017
# 1975.0
# Amazonas August 2017
# 6316.0
# Amazonas September 2017
# 4033.0
# Amazonas October 2017
# 1581.0
# Amazonas November 2017
# 552.0
# Amazonas December 2017
# 119.0
# [4.0, 9.0, 55.5, 8.5, 30.5, 152.5, 107.5, 61.0, 21.5, 63.5, 24.0, 57.5, 119.5, 87.0, 62.5, 138.0, 138.0, 231.5, 433.0, 119.0]
# Bahia January 1998
# 0.0
# Bahia Feburary 1998
# 0.0
# Bahia March 1998
# 0.0
# Bahia April 1998
# 0.0
# Bahia May 1998
# 0.0
# Bahia June 1998
# 55.0
# Bahia July 1998
# 219.0
# Bahia August 1998
# 815.0
# Bahia September 1998
# 2718.0
# Bahia October 1998
# 1969.0
# Bahia November 1998
# 49.0
# Bahia December 1998
# 82.0
# 52.0
# Bahia January 1999
# 114.0
# Bahia Feburary 1999
# 157.0
# Bahia March 1999
# 83.0
# Bahia April 1999
# 55.0
# Bahia May 1999
# 76.0
# Bahia June 1999
# 64.0
# Bahia July 1999
# 107.0
# Bahia August 1999
# 453.0
# Bahia September 1999
# 1275.0
# Bahia October 1999
# 1307.0
# Bahia November 1999
# 49.0
# Bahia December 1999
# 37.0
# 95.0
# Bahia January 2000
# 31.0
# Bahia Feburary 2000
# 32.0
# Bahia March 2000
# 65.0
# Bahia April 2000
# 23.0
# Bahia May 2000
# 71.0
# Bahia June 2000
# 178.0
# Bahia July 2000
# 202.0
# Bahia August 2000
# 633.0
# Bahia September 2000
# 2285.0
# Bahia October 2000
# 335.0
# Bahia November 2000
# 114.0
# Bahia December 2000
# 24.0
# 92.5
# Bahia January 2001
# 24.0
# Bahia Feburary 2001
# 101.0
# Bahia March 2001
# 4.0
# Bahia April 2001
# 26.0
# Bahia May 2001
# 85.0
# Bahia June 2001
# 98.0
# Bahia July 2001
# 248.0
# Bahia August 2001
# 979.0
# Bahia September 2001
# 3964.0
# Bahia October 2001
# 1687.0
# Bahia November 2001
# 699.0
# Bahia December 2001
# 158.0
# 129.5
# Bahia January 2002
# 125.0
# Bahia Feburary 2002
# 204.0
# Bahia March 2002
# 146.0
# Bahia April 2002
# 110.0
# Bahia May 2002
# 166.0
# Bahia June 2002
# 118.0
# Bahia July 2002
# 549.0
# Bahia August 2002
# 1827.0
# Bahia September 2002
# 6439.0
# Bahia October 2002
# 5414.0
# Bahia November 2002
# 1020.0
# Bahia December 2002
# 848.0
# 376.5
# Bahia January 2003
# 439.0
# Bahia Feburary 2003
# 223.0
# Bahia March 2003
# 274.0
# Bahia April 2003
# 376.0
# Bahia May 2003
# 106.0
# Bahia June 2003
# 140.0
# Bahia July 2003
# 261.0
# Bahia August 2003
# 1039.0
# Bahia September 2003
# 8847.0
# Bahia October 2003
# 4264.0
# Bahia November 2003
# 533.0
# Bahia December 2003
# 710.0
# 407.5
# Bahia January 2004
# 158.0
# Bahia Feburary 2004
# 122.0
# Bahia March 2004
# 115.0
# Bahia April 2004
# 89.0
# Bahia May 2004
# 124.0
# Bahia June 2004
# 289.0
# Bahia July 2004
# 310.0
# Bahia August 2004
# 1430.0
# Bahia September 2004
# 6433.0
# Bahia October 2004
# 4810.0
# Bahia November 2004
# 1736.0
# Bahia December 2004
# 423.0
# 299.5
# Bahia January 2005
# 303.0
# Bahia Feburary 2005
# 143.0
# Bahia March 2005
# 158.0
# Bahia April 2005
# 76.0
# Bahia May 2005
# 120.0
# Bahia June 2005
# 211.0
# Bahia July 2005
# 269.0
# Bahia August 2005
# 948.0
# Bahia September 2005
# 4066.0
# Bahia October 2005
# 8405.0
# Bahia November 2005
# 1595.0
# Bahia December 2005
# 116.0
# 240.0
# Bahia January 2006
# 225.0
# Bahia Feburary 2006
# 277.0
# Bahia March 2006
# 199.0
# Bahia April 2006
# 60.0
# Bahia May 2006
# 43.0
# Bahia June 2006
# 68.0
# Bahia July 2006
# 229.0
# Bahia August 2006
# 995.0
# Bahia September 2006
# 3006.0
# Bahia October 2006
# 2079.0
# Bahia November 2006
# 239.0
# Bahia December 2006
# 169.0
# 227.0
# Bahia January 2007
# 373.0
# Bahia Feburary 2007
# 113.0
# Bahia March 2007
# 141.0
# Bahia April 2007
# 64.0
# Bahia May 2007
# 161.0
# Bahia June 2007
# 270.0
# Bahia July 2007
# 811.0
# Bahia August 2007
# 3734.0
# Bahia September 2007
# 7438.0
# Bahia October 2007
# 4981.0
# Bahia November 2007
# 2126.0
# Bahia December 2007
# 259.0
# 321.5
# Bahia January 2008
# 314.0
# Bahia Feburary 2008
# 235.0
# Bahia March 2008
# 135.0
# Bahia April 2008
# 151.0
# Bahia May 2008
# 56.0
# Bahia June 2008
# 72.0
# Bahia July 2008
# 271.0
# Bahia August 2008
# 611.0
# Bahia September 2008
# 4837.0
# Bahia October 2008
# 7691.0
# Bahia November 2008
# 3175.0
# Bahia December 2008
# 52.0
# 253.0
# Bahia January 2009
# 177.0
# Bahia Feburary 2009
# 117.0
# Bahia March 2009
# 249.0
# Bahia April 2009
# 40.0
# Bahia May 2009
# 34.0
# Bahia June 2009
# 92.0
# Bahia July 2009
# 321.0
# Bahia August 2009
# 439.0
# Bahia September 2009
# 3610.0
# Bahia October 2009
# 2552.0
# Bahia November 2009
# 402.0
# Bahia December 2009
# 308.0
# 278.5
# Bahia January 2010
# 297.0
# Bahia Feburary 2010
# 206.0
# Bahia March 2010
# 156.0
# Bahia April 2010
# 103.0
# Bahia May 2010
# 198.0
# Bahia June 2010
# 192.0
# Bahia July 2010
# 519.0
# Bahia August 2010
# 2423.0
# Bahia September 2010
# 5323.0
# Bahia October 2010
# 5264.0
# Bahia November 2010
# 605.0
# Bahia December 2010
# 226.0
# 261.5
# Bahia January 2011
# 101.0
# Bahia Feburary 2011
# 156.0
# Bahia March 2011
# 90.0
# Bahia April 2011
# 149.0
# Bahia May 2011
# 189.0
# Bahia June 2011
# 345.0
# Bahia July 2011
# 578.0
# Bahia August 2011
# 1795.0
# Bahia September 2011
# 7086.0
# Bahia October 2011
# 2166.0
# Bahia November 2011
# 176.0
# Bahia December 2011
# 230.0
# 209.5
# Bahia January 2012
# 179.0
# Bahia Feburary 2012
# 200.0
# Bahia March 2012
# 404.0
# Bahia April 2012
# 396.0
# Bahia May 2012
# 326.0
# Bahia June 2012
# 385.0
# Bahia July 2012
# 906.0
# Bahia August 2012
# 1835.0
# Bahia September 2012
# 7495.0
# Bahia October 2012
# 4607.0
# Bahia November 2012
# 168.0
# Bahia December 2012
# 477.0
# 400.0
# Bahia January 2013
# 125.0
# Bahia Feburary 2013
# 231.0
# Bahia March 2013
# 363.0
# Bahia April 2013
# 108.0
# Bahia May 2013
# 141.0
# Bahia June 2013
# 208.0
# Bahia July 2013
# 362.0
# Bahia August 2013
# 610.0
# Bahia September 2013
# 2681.0
# Bahia October 2013
# 1969.0
# Bahia November 2013
# 288.0
# Bahia December 2013
# 131.0
# 259.5
# Bahia January 2014
# 132.0
# Bahia Feburary 2014
# 107.0
# Bahia March 2014
# 148.0
# Bahia April 2014
# 183.0
# Bahia May 2014
# 224.0
# Bahia June 2014
# 243.0
# Bahia July 2014
# 249.0
# Bahia August 2014
# 674.0
# Bahia September 2014
# 2604.0
# Bahia October 2014
# 2763.0
# Bahia November 2014
# 348.0
# Bahia December 2014
# 144.0
# 233.5
# Bahia January 2015
# 256.0
# Bahia Feburary 2015
# 143.0
# Bahia March 2015
# 229.0
# Bahia April 2015
# 190.0
# Bahia May 2015
# 144.0
# Bahia June 2015
# 242.0
# Bahia July 2015
# 306.0
# Bahia August 2015
# 829.0
# Bahia September 2015
# 7956.0
# Bahia October 2015
# 4989.0
# Bahia November 2015
# 1705.0
# Bahia December 2015
# 1408.0
# 281.0
# Bahia January 2016
# 285.0
# Bahia Feburary 2016
# 418.0
# Bahia March 2016
# 281.0
# Bahia April 2016
# 217.0
# Bahia May 2016
# 259.0
# Bahia June 2016
# 416.0
# Bahia July 2016
# 345.0
# Bahia August 2016
# 724.0
# Bahia September 2016
# 1819.0
# Bahia October 2016
# 1415.0
# Bahia November 2016
# 408.0
# Bahia December 2016
# 164.0
# 376.5
# Bahia January 2017
# 154.0
# Bahia Feburary 2017
# 100.0
# Bahia March 2017
# 163.0
# Bahia April 2017
# 94.0
# Bahia May 2017
# 121.0
# Bahia June 2017
# 329.0
# Bahia July 2017
# 300.0
# Bahia August 2017
# 1018.0
# Bahia September 2017
# 1791.0
# Bahia October 2017
# 4005.0
# Bahia November 2017
# 174.0
# Bahia December 2017
# 174.0
# [52.0, 95.0, 92.5, 129.5, 376.5, 407.5, 299.5, 240.0, 227.0, 321.5, 253.0, 278.5, 261.5, 209.5, 400.0, 259.5, 233.5, 281.0, 376.5, 174.0]
# Ceara January 1998
# 0.0
# Ceara Feburary 1998
# 0.0
# Ceara March 1998
# 0.0
# Ceara April 1998
# 0.0
# Ceara May 1998
# 0.0
# Ceara June 1998
# 1.0
# Ceara July 1998
# 76.0
# Ceara August 1998
# 93.0
# Ceara September 1998
# 590.0
# Ceara October 1998
# 1014.0
# Ceara November 1998
# 575.0
# Ceara December 1998
# 276.0
# 38.5
# Ceara January 1999
# 47.0
# Ceara Feburary 1999
# 16.0
# Ceara March 1999
# 30.0
# Ceara April 1999
# 6.0
# Ceara May 1999
# 5.0
# Ceara June 1999
# 16.0
# Ceara July 1999
# 83.0
# Ceara August 1999
# 131.0
# Ceara September 1999
# 124.0
# Ceara October 1999
# 309.0
# Ceara November 1999
# 524.0
# Ceara December 1999
# 397.0
# 65.0
# Ceara January 2000
# 1.0
# Ceara Feburary 2000
# 6.0
# Ceara March 2000
# 9.0
# Ceara April 2000
# 15.0
# Ceara May 2000
# 7.0
# Ceara June 2000
# 16.0
# Ceara July 2000
# 18.0
# Ceara August 2000
# 79.0
# Ceara September 2000
# 127.0
# Ceara October 2000
# 875.0
# Ceara November 2000
# 669.0
# Ceara December 2000
# 389.0
# 17.0
# Ceara January 2001
# 11.0
# Ceara Feburary 2001
# 0.0
# Ceara March 2001
# 0.0
# Ceara April 2001
# 2.0
# Ceara May 2001
# 81.0
# Ceara June 2001
# 38.0
# Ceara July 2001
# 146.0
# Ceara August 2001
# 219.0
# Ceara September 2001
# 801.0
# Ceara October 2001
# 2045.0
# Ceara November 2001
# 2456.0
# Ceara December 2001
# 545.0
# 113.5
# Ceara January 2002
# 33.0
# Ceara Feburary 2002
# 75.0
# Ceara March 2002
# 17.0
# Ceara April 2002
# 5.0
# Ceara May 2002
# 10.0
# Ceara June 2002
# 13.0
# Ceara July 2002
# 12.0
# Ceara August 2002
# 111.0
# Ceara September 2002
# 172.0
# Ceara October 2002
# 1606.0
# Ceara November 2002
# 2715.0
# Ceara December 2002
# 1787.0
# 54.0
# Ceara January 2003
# 264.0
# Ceara Feburary 2003
# 9.0
# Ceara March 2003
# 3.0
# Ceara April 2003
# 3.0
# Ceara May 2003
# 0.0
# Ceara June 2003
# 2.0
# Ceara July 2003
# 14.0
# Ceara August 2003
# 109.0
# Ceara September 2003
# 384.0
# Ceara October 2003
# 1761.0
# Ceara November 2003
# 3327.0
# Ceara December 2003
# 2436.0
# 61.5
# Ceara January 2004
# 143.0
# Ceara Feburary 2004
# 5.0
# Ceara March 2004
# 1.0
# Ceara April 2004
# 2.0
# Ceara May 2004
# 3.0
# Ceara June 2004
# 1.0
# Ceara July 2004
# 16.0
# Ceara August 2004
# 61.0
# Ceara September 2004
# 144.0
# Ceara October 2004
# 1217.0
# Ceara November 2004
# 29.0
# Ceara December 2004
# 3158.0
# 22.5
# Ceara January 2005
# 384.0
# Ceara Feburary 2005
# 25.0
# Ceara March 2005
# 5.0
# Ceara April 2005
# 4.0
# Ceara May 2005
# 1.0
# Ceara June 2005
# 6.0
# Ceara July 2005
# 14.0
# Ceara August 2005
# 51.0
# Ceara September 2005
# 185.0
# Ceara October 2005
# 1378.0
# Ceara November 2005
# 2483.0
# Ceara December 2005
# 1360.0
# 38.0
# Ceara January 2006
# 211.0
# Ceara Feburary 2006
# 23.0
# Ceara March 2006
# 3.0
# Ceara April 2006
# 1.0
# Ceara May 2006
# 0.0
# Ceara June 2006
# 0.0
# Ceara July 2006
# 1.0
# Ceara August 2006
# 50.0
# Ceara September 2006
# 237.0
# Ceara October 2006
# 581.0
# Ceara November 2006
# 1012.0
# Ceara December 2006
# 1161.0
# 36.5
# Ceara January 2007
# 304.0
# Ceara Feburary 2007
# 3.0
# Ceara March 2007
# 2.0
# Ceara April 2007
# 1.0
# Ceara May 2007
# 0.0
# Ceara June 2007
# 1.0
# Ceara July 2007
# 11.0
# Ceara August 2007
# 182.0
# Ceara September 2007
# 241.0
# Ceara October 2007
# 964.0
# Ceara November 2007
# 1443.0
# Ceara December 2007
# 1177.0
# 96.5
# Ceara January 2008
# 166.0
# Ceara Feburary 2008
# 12.0
# Ceara March 2008
# 2.0
# Ceara April 2008
# 0.0
# Ceara May 2008
# 0.0
# Ceara June 2008
# 1.0
# Ceara July 2008
# 3.0
# Ceara August 2008
# 32.0
# Ceara September 2008
# 177.0
# Ceara October 2008
# 816.0
# Ceara November 2008
# 1753.0
# Ceara December 2008
# 1655.0
# 22.0
# Ceara January 2009
# 347.0
# Ceara Feburary 2009
# 8.0
# Ceara March 2009
# 3.0
# Ceara April 2009
# 0.0
# Ceara May 2009
# 0.0
# Ceara June 2009
# 0.0
# Ceara July 2009
# 7.0
# Ceara August 2009
# 26.0
# Ceara September 2009
# 101.0
# Ceara October 2009
# 435.0
# Ceara November 2009
# 1653.0
# Ceara December 2009
# 1987.0
# 17.0
# Ceara January 2010
# 288.0
# Ceara Feburary 2010
# 63.0
# Ceara March 2010
# 40.0
# Ceara April 2010
# 7.0
# Ceara May 2010
# 2.0
# Ceara June 2010
# 3.0
# Ceara July 2010
# 44.0
# Ceara August 2010
# 202.0
# Ceara September 2010
# 357.0
# Ceara October 2010
# 502.0
# Ceara November 2010
# 1652.0
# Ceara December 2010
# 578.0
# 132.5
# Ceara January 2011
# 32.0
# Ceara Feburary 2011
# 2.0
# Ceara March 2011
# 6.0
# Ceara April 2011
# 1.0
# Ceara May 2011
# 0.0
# Ceara June 2011
# 5.0
# Ceara July 2011
# 18.0
# Ceara August 2011
# 53.0
# Ceara September 2011
# 239.0
# Ceara October 2011
# 415.0
# Ceara November 2011
# 1561.0
# Ceara December 2011
# 1441.0
# 25.0
# Ceara January 2012
# 273.0
# Ceara Feburary 2012
# 41.0
# Ceara March 2012
# 10.0
# Ceara April 2012
# 2.0
# Ceara May 2012
# 19.0
# Ceara June 2012
# 28.0
# Ceara July 2012
# 50.0
# Ceara August 2012
# 278.0
# Ceara September 2012
# 609.0
# Ceara October 2012
# 1104.0
# Ceara November 2012
# 995.0
# Ceara December 2012
# 631.0
# 161.5
# Ceara January 2013
# 103.0
# Ceara Feburary 2013
# 49.0
# Ceara March 2013
# 17.0
# Ceara April 2013
# 4.0
# Ceara May 2013
# 4.0
# Ceara June 2013
# 5.0
# Ceara July 2013
# 4.0
# Ceara August 2013
# 32.0
# Ceara September 2013
# 177.0
# Ceara October 2013
# 466.0
# Ceara November 2013
# 1081.0
# Ceara December 2013
# 956.0
# 40.5
# Ceara January 2014
# 115.0
# Ceara Feburary 2014
# 18.0
# Ceara March 2014
# 6.0
# Ceara April 2014
# 4.0
# Ceara May 2014
# 4.0
# Ceara June 2014
# 19.0
# Ceara July 2014
# 47.0
# Ceara August 2014
# 155.0
# Ceara September 2014
# 155.0
# Ceara October 2014
# 517.0
# Ceara November 2014
# 829.0
# Ceara December 2014
# 643.0
# 81.0
# Ceara January 2015
# 207.0
# Ceara Feburary 2015
# 25.0
# Ceara March 2015
# 20.0
# Ceara April 2015
# 3.0
# Ceara May 2015
# 17.0
# Ceara June 2015
# 22.0
# Ceara July 2015
# 25.0
# Ceara August 2015
# 127.0
# Ceara September 2015
# 214.0
# Ceara October 2015
# 658.0
# Ceara November 2015
# 1081.0
# Ceara December 2015
# 1021.0
# 76.0
# Ceara January 2016
# 100.0
# Ceara Feburary 2016
# 13.0
# Ceara March 2016
# 4.0
# Ceara April 2016
# 10.0
# Ceara May 2016
# 8.0
# Ceara June 2016
# 45.0
# Ceara July 2016
# 124.0
# Ceara August 2016
# 293.0
# Ceara September 2016
# 370.0
# Ceara October 2016
# 1310.0
# Ceara November 2016
# 1328.0
# Ceara December 2016
# 819.0
# 112.0
# Ceara January 2017
# 91.0
# Ceara Feburary 2017
# 9.0
# Ceara March 2017
# 4.0
# Ceara April 2017
# 6.0
# Ceara May 2017
# 9.0
# Ceara June 2017
# 23.0
# Ceara July 2017
# 26.0
# Ceara August 2017
# 121.0
# Ceara September 2017
# 505.0
# Ceara October 2017
# 949.0
# Ceara November 2017
# 812.0
# Ceara December 2017
# 26.0
# [38.5, 65.0, 17.0, 113.5, 54.0, 61.5, 22.5, 38.0, 36.5, 96.5, 22.0, 17.0, 132.5, 25.0, 161.5, 40.5, 81.0, 76.0, 112.0, 26.0]
# Distrito Federal January 1998
# 0.0
# Distrito Federal Feburary 1998
# 0.0
# Distrito Federal March 1998
# 0.0
# Distrito Federal April 1998
# 0.0
# Distrito Federal May 1998
# 0.0
# Distrito Federal June 1998
# 2.0
# Distrito Federal July 1998
# 17.0
# Distrito Federal August 1998
# 48.0
# Distrito Federal September 1998
# 33.0
# Distrito Federal October 1998
# 3.0
# Distrito Federal November 1998
# 0.0
# Distrito Federal December 1998
# 0.0
# 0.0
# Distrito Federal January 1999
# 0.0
# Distrito Federal Feburary 1999
# 2.0
# Distrito Federal March 1999
# 0.0
# Distrito Federal April 1999
# 0.0
# Distrito Federal May 1999
# 0.0
# Distrito Federal June 1999
# 3.0
# Distrito Federal July 1999
# 4.0
# Distrito Federal August 1999
# 16.0
# Distrito Federal September 1999
# 12.0
# Distrito Federal October 1999
# 8.0
# Distrito Federal November 1999
# 1.0
# Distrito Federal December 1999
# 0.0
# 1.5
# Distrito Federal January 2000
# 0.0
# Distrito Federal Feburary 2000
# 0.0
# Distrito Federal March 2000
# 0.0
# Distrito Federal April 2000
# 0.0
# Distrito Federal May 2000
# 2.0
# Distrito Federal June 2000
# 1.0
# Distrito Federal July 2000
# 15.0
# Distrito Federal August 2000
# 9.0
# Distrito Federal September 2000
# 3.0
# Distrito Federal October 2000
# 18.0
# Distrito Federal November 2000
# 0.0
# Distrito Federal December 2000
# 0.0
# 0.5
# Distrito Federal January 2001
# 0.0
# Distrito Federal Feburary 2001
# 1.0
# Distrito Federal March 2001
# 0.0
# Distrito Federal April 2001
# 0.0
# Distrito Federal May 2001
# 0.0
# Distrito Federal June 2001
# 3.0
# Distrito Federal July 2001
# 22.0
# Distrito Federal August 2001
# 25.0
# Distrito Federal September 2001
# 12.0
# Distrito Federal October 2001
# 0.0
# Distrito Federal November 2001
# 0.0
# Distrito Federal December 2001
# 1.0
# 0.5
# Distrito Federal January 2002
# 0.0
# Distrito Federal Feburary 2002
# 0.0
# Distrito Federal March 2002
# 0.0
# Distrito Federal April 2002
# 1.0
# Distrito Federal May 2002
# 1.0
# Distrito Federal June 2002
# 7.0
# Distrito Federal July 2002
# 33.0
# Distrito Federal August 2002
# 53.0
# Distrito Federal September 2002
# 33.0
# Distrito Federal October 2002
# 19.0
# Distrito Federal November 2002
# 1.0
# Distrito Federal December 2002
# 1.0
# 1.0
# Distrito Federal January 2003
# 0.0
# Distrito Federal Feburary 2003
# 1.0
# Distrito Federal March 2003
# 0.0
# Distrito Federal April 2003
# 0.0
# Distrito Federal May 2003
# 0.0
# Distrito Federal June 2003
# 11.0
# Distrito Federal July 2003
# 19.0
# Distrito Federal August 2003
# 36.0
# Distrito Federal September 2003
# 17.0
# Distrito Federal October 2003
# 12.0
# Distrito Federal November 2003
# 0.0
# Distrito Federal December 2003
# 0.0
# 0.5
# Distrito Federal January 2004
# 0.0
# Distrito Federal Feburary 2004
# 0.0
# Distrito Federal March 2004
# 0.0
# Distrito Federal April 2004
# 1.0
# Distrito Federal May 2004
# 9.0
# Distrito Federal June 2004
# 6.0
# Distrito Federal July 2004
# 37.0
# Distrito Federal August 2004
# 108.0
# Distrito Federal September 2004
# 100.0
# Distrito Federal October 2004
# 18.0
# Distrito Federal November 2004
# 0.0
# Distrito Federal December 2004
# 0.0
# 3.5
# Distrito Federal January 2005
# 0.0
# Distrito Federal Feburary 2005
# 0.0
# Distrito Federal March 2005
# 0.0
# Distrito Federal April 2005
# 0.0
# Distrito Federal May 2005
# 2.0
# Distrito Federal June 2005
# 3.0
# Distrito Federal July 2005
# 24.0
# Distrito Federal August 2005
# 20.0
# Distrito Federal September 2005
# 23.0
# Distrito Federal October 2005
# 18.0
# Distrito Federal November 2005
# 2.0
# Distrito Federal December 2005
# 0.0
# 2.0
# Distrito Federal January 2006
# 0.0
# Distrito Federal Feburary 2006
# 0.0
# Distrito Federal March 2006
# 0.0
# Distrito Federal April 2006
# 0.0
# Distrito Federal May 2006
# 3.0
# Distrito Federal June 2006
# 2.0
# Distrito Federal July 2006
# 10.0
# Distrito Federal August 2006
# 40.0
# Distrito Federal September 2006
# 20.0
# Distrito Federal October 2006
# 1.0
# Distrito Federal November 2006
# 0.0
# Distrito Federal December 2006
# 0.0
# 0.5
# Distrito Federal January 2007
# 0.0
# Distrito Federal Feburary 2007
# 0.0
# Distrito Federal March 2007
# 1.0
# Distrito Federal April 2007
# 0.0
# Distrito Federal May 2007
# 4.0
# Distrito Federal June 2007
# 21.0
# Distrito Federal July 2007
# 25.0
# Distrito Federal August 2007
# 137.0
# Distrito Federal September 2007
# 73.0
# Distrito Federal October 2007
# 13.0
# Distrito Federal November 2007
# 0.0
# Distrito Federal December 2007
# 0.0
# 2.5
# Distrito Federal January 2008
# 0.0
# Distrito Federal Feburary 2008
# 0.0
# Distrito Federal March 2008
# 2.0
# Distrito Federal April 2008
# 1.0
# Distrito Federal May 2008
# 6.0
# Distrito Federal June 2008
# 0.0
# Distrito Federal July 2008
# 12.0
# Distrito Federal August 2008
# 30.0
# Distrito Federal September 2008
# 54.0
# Distrito Federal October 2008
# 6.0
# Distrito Federal November 2008
# 4.0
# Distrito Federal December 2008
# 0.0
# 3.0
# Distrito Federal January 2009
# 1.0
# Distrito Federal Feburary 2009
# 0.0
# Distrito Federal March 2009
# 0.0
# Distrito Federal April 2009
# 0.0
# Distrito Federal May 2009
# 9.0
# Distrito Federal June 2009
# 4.0
# Distrito Federal July 2009
# 33.0
# Distrito Federal August 2009
# 37.0
# Distrito Federal September 2009
# 5.0
# Distrito Federal October 2009
# 3.0
# Distrito Federal November 2009
# 0.0
# Distrito Federal December 2009
# 0.0
# 2.0
# Distrito Federal January 2010
# 2.0
# Distrito Federal Feburary 2010
# 4.0
# Distrito Federal March 2010
# 0.0
# Distrito Federal April 2010
# 8.0
# Distrito Federal May 2010
# 23.0
# Distrito Federal June 2010
# 21.0
# Distrito Federal July 2010
# 85.0
# Distrito Federal August 2010
# 159.0
# Distrito Federal September 2010
# 196.0
# Distrito Federal October 2010
# 6.0
# Distrito Federal November 2010
# 0.0
# Distrito Federal December 2010
# 1.0
# 7.0
# Distrito Federal January 2011
# 2.0
# Distrito Federal Feburary 2011
# 1.0
# Distrito Federal March 2011
# 0.0
# Distrito Federal April 2011
# 1.0
# Distrito Federal May 2011
# 3.0
# Distrito Federal June 2011
# 18.0
# Distrito Federal July 2011
# 53.0
# Distrito Federal August 2011
# 61.0
# Distrito Federal September 2011
# 133.0
# Distrito Federal October 2011
# 0.0
# Distrito Federal November 2011
# 1.0
# Distrito Federal December 2011
# 0.0
# 1.5
# Distrito Federal January 2012
# 0.0
# Distrito Federal Feburary 2012
# 0.0
# Distrito Federal March 2012
# 0.0
# Distrito Federal April 2012
# 4.0
# Distrito Federal May 2012
# 0.0
# Distrito Federal June 2012
# 6.0
# Distrito Federal July 2012
# 29.0
# Distrito Federal August 2012
# 55.0
# Distrito Federal September 2012
# 64.0
# Distrito Federal October 2012
# 15.0
# Distrito Federal November 2012
# 0.0
# Distrito Federal December 2012
# 0.0
# 2.0
# Distrito Federal January 2013
# 0.0
# Distrito Federal Feburary 2013
# 1.0
# Distrito Federal March 2013
# 1.0
# Distrito Federal April 2013
# 1.0
# Distrito Federal May 2013
# 2.0
# Distrito Federal June 2013
# 4.0
# Distrito Federal July 2013
# 22.0
# Distrito Federal August 2013
# 34.0
# Distrito Federal September 2013
# 31.0
# Distrito Federal October 2013
# 3.0
# Distrito Federal November 2013
# 0.0
# Distrito Federal December 2013
# 2.0
# 2.0
# Distrito Federal January 2014
# 0.0
# Distrito Federal Feburary 2014
# 1.0
# Distrito Federal March 2014
# 1.0
# Distrito Federal April 2014
# 2.0
# Distrito Federal May 2014
# 9.0
# Distrito Federal June 2014
# 6.0
# Distrito Federal July 2014
# 27.0
# Distrito Federal August 2014
# 99.0
# Distrito Federal September 2014
# 72.0
# Distrito Federal October 2014
# 34.0
# Distrito Federal November 2014
# 0.0
# Distrito Federal December 2014
# 0.0
# 4.0
# Distrito Federal January 2015
# 1.0
# Distrito Federal Feburary 2015
# 0.0
# Distrito Federal March 2015
# 0.0
# Distrito Federal April 2015
# 0.0
# Distrito Federal May 2015
# 2.0
# Distrito Federal June 2015
# 1.0
# Distrito Federal July 2015
# 15.0
# Distrito Federal August 2015
# 53.0
# Distrito Federal September 2015
# 76.0
# Distrito Federal October 2015
# 21.0
# Distrito Federal November 2015
# 3.0
# Distrito Federal December 2015
# 0.0
# 1.5
# Distrito Federal January 2016
# 1.0
# Distrito Federal Feburary 2016
# 2.0
# Distrito Federal March 2016
# 1.0
# Distrito Federal April 2016
# 5.0
# Distrito Federal May 2016
# 15.0
# Distrito Federal June 2016
# 42.0
# Distrito Federal July 2016
# 79.0
# Distrito Federal August 2016
# 29.0
# Distrito Federal September 2016
# 58.0
# Distrito Federal October 2016
# 9.0
# Distrito Federal November 2016
# 1.0
# Distrito Federal December 2016
# 0.0
# 7.0
# Distrito Federal January 2017
# 1.0
# Distrito Federal Feburary 2017
# 0.0
# Distrito Federal March 2017
# 0.0
# Distrito Federal April 2017
# 1.0
# Distrito Federal May 2017
# 6.0
# Distrito Federal June 2017
# 23.0
# Distrito Federal July 2017
# 44.0
# Distrito Federal August 2017
# 147.0
# Distrito Federal September 2017
# 122.0
# Distrito Federal October 2017
# 66.0
# Distrito Federal November 2017
# 0.0
# Distrito Federal December 2017
# 6.0
# [0.0, 1.5, 0.5, 0.5, 1.0, 0.5, 3.5, 2.0, 0.5, 2.5, 3.0, 2.0, 7.0, 1.5, 2.0, 2.0, 4.0, 1.5, 7.0, 6.0]
# Espirito Santo January 1998
# 0.0
# Espirito Santo Feburary 1998
# 0.0
# Espirito Santo March 1998
# 0.0
# Espirito Santo April 1998
# 0.0
# Espirito Santo May 1998
# 0.0
# Espirito Santo June 1998
# 6.0
# Espirito Santo July 1998
# 37.0
# Espirito Santo August 1998
# 38.0
# Espirito Santo September 1998
# 108.0
# Espirito Santo October 1998
# 20.0
# Espirito Santo November 1998
# 4.0
# Espirito Santo December 1998
# 5.0
# 4.5
# Espirito Santo January 1999
# 33.0
# Espirito Santo Feburary 1999
# 10.0
# Espirito Santo March 1999
# 8.0
# Espirito Santo April 1999
# 2.0
# Espirito Santo May 1999
# 16.0
# Espirito Santo June 1999
# 6.0
# Espirito Santo July 1999
# 9.0
# Espirito Santo August 1999
# 60.0
# Espirito Santo September 1999
# 64.0
# Espirito Santo October 1999
# 23.0
# Espirito Santo November 1999
# 9.0
# Espirito Santo December 1999
# 0.0
# 9.5
# Espirito Santo January 2000
# 5.0
# Espirito Santo Feburary 2000
# 5.0
# Espirito Santo March 2000
# 1.0
# Espirito Santo April 2000
# 3.0
# Espirito Santo May 2000
# 2.0
# Espirito Santo June 2000
# 9.0
# Espirito Santo July 2000
# 16.0
# Espirito Santo August 2000
# 26.0
# Espirito Santo September 2000
# 14.0
# Espirito Santo October 2000
# 88.0
# Espirito Santo November 2000
# 3.0
# Espirito Santo December 2000
# 3.0
# 5.0
# Espirito Santo January 2001
# 1.0
# Espirito Santo Feburary 2001
# 5.0
# Espirito Santo March 2001
# 2.0
# Espirito Santo April 2001
# 2.0
# Espirito Santo May 2001
# 8.0
# Espirito Santo June 2001
# 9.0
# Espirito Santo July 2001
# 12.0
# Espirito Santo August 2001
# 30.0
# Espirito Santo September 2001
# 38.0
# Espirito Santo October 2001
# 19.0
# Espirito Santo November 2001
# 3.0
# Espirito Santo December 2001
# 1.0
# 6.5
# Espirito Santo January 2002
# 2.0
# Espirito Santo Feburary 2002
# 4.0
# Espirito Santo March 2002
# 4.0
# Espirito Santo April 2002
# 2.0
# Espirito Santo May 2002
# 5.0
# Espirito Santo June 2002
# 18.0
# Espirito Santo July 2002
# 9.0
# Espirito Santo August 2002
# 60.0
# Espirito Santo September 2002
# 46.0
# Espirito Santo October 2002
# 113.0
# Espirito Santo November 2002
# 22.0
# Espirito Santo December 2002
# 12.0
# 10.5
# Espirito Santo January 2003
# 4.0
# Espirito Santo Feburary 2003
# 11.0
# Espirito Santo March 2003
# 28.0
# Espirito Santo April 2003
# 22.0
# Espirito Santo May 2003
# 1.0
# Espirito Santo June 2003
# 19.0
# Espirito Santo July 2003
# 27.0
# Espirito Santo August 2003
# 118.0
# Espirito Santo September 2003
# 252.0
# Espirito Santo October 2003
# 159.0
# Espirito Santo November 2003
# 49.0
# Espirito Santo December 2003
# 18.0
# 24.5
# Espirito Santo January 2004
# 1.0
# Espirito Santo Feburary 2004
# 5.0
# Espirito Santo March 2004
# 3.0
# Espirito Santo April 2004
# 0.0
# Espirito Santo May 2004
# 0.0
# Espirito Santo June 2004
# 3.0
# Espirito Santo July 2004
# 4.0
# Espirito Santo August 2004
# 12.0
# Espirito Santo September 2004
# 47.0
# Espirito Santo October 2004
# 48.0
# Espirito Santo November 2004
# 42.0
# Espirito Santo December 2004
# 9.0
# 4.5
# Espirito Santo January 2005
# 4.0
# Espirito Santo Feburary 2005
# 1.0
# Espirito Santo March 2005
# 3.0
# Espirito Santo April 2005
# 4.0
# Espirito Santo May 2005
# 5.0
# Espirito Santo June 2005
# 8.0
# Espirito Santo July 2005
# 9.0
# Espirito Santo August 2005
# 12.0
# Espirito Santo September 2005
# 8.0
# Espirito Santo October 2005
# 62.0
# Espirito Santo November 2005
# 0.0
# Espirito Santo December 2005
# 5.0
# 5.0
# Espirito Santo January 2006
# 13.0
# Espirito Santo Feburary 2006
# 45.0
# Espirito Santo March 2006
# 14.0
# Espirito Santo April 2006
# 1.0
# Espirito Santo May 2006
# 0.0
# Espirito Santo June 2006
# 5.0
# Espirito Santo July 2006
# 11.0
# Espirito Santo August 2006
# 29.0
# Espirito Santo September 2006
# 87.0
# Espirito Santo October 2006
# 10.0
# Espirito Santo November 2006
# 0.0
# Espirito Santo December 2006
# 0.0
# 10.5
# Espirito Santo January 2007
# 0.0
# Espirito Santo Feburary 2007
# 3.0
# Espirito Santo March 2007
# 9.0
# Espirito Santo April 2007
# 2.0
# Espirito Santo May 2007
# 1.0
# Espirito Santo June 2007
# 4.0
# Espirito Santo July 2007
# 13.0
# Espirito Santo August 2007
# 82.0
# Espirito Santo September 2007
# 63.0
# Espirito Santo October 2007
# 79.0
# Espirito Santo November 2007
# 112.0
# Espirito Santo December 2007
# 14.0
# 11.0
# Espirito Santo January 2008
# 12.0
# Espirito Santo Feburary 2008
# 20.0
# Espirito Santo March 2008
# 5.0
# Espirito Santo April 2008
# 8.0
# Espirito Santo May 2008
# 2.0
# Espirito Santo June 2008
# 4.0
# ...
# 37.0
# 75.0
# Sao Paulo January 2010
# 45.0
# Sao Paulo Feburary 2010
# 152.0
# Sao Paulo March 2010
# 111.0
# Sao Paulo April 2010
# 91.0
# Sao Paulo May 2010
# 150.0
# Sao Paulo June 2010
# 143.0
# Sao Paulo July 2010
# 600.0
# Sao Paulo August 2010
# 1809.0
# Sao Paulo September 2010
# 1677.0
# Sao Paulo October 2010
# 260.0
# Sao Paulo November 2010
# 104.0
# Sao Paulo December 2010
# 52.0
# 146.5
# Sao Paulo January 2011
# 75.0
# Sao Paulo Feburary 2011
# 73.0
# Sao Paulo March 2011
# 45.0
# Sao Paulo April 2011
# 52.0
# Sao Paulo May 2011
# 136.0
# Sao Paulo June 2011
# 210.0
# Sao Paulo July 2011
# 479.0
# Sao Paulo August 2011
# 1067.0
# Sao Paulo September 2011
# 1108.0
# Sao Paulo October 2011
# 188.0
# Sao Paulo November 2011
# 87.0
# Sao Paulo December 2011
# 53.0
# 111.5
# Sao Paulo January 2012
# 38.0
# Sao Paulo Feburary 2012
# 81.0
# Sao Paulo March 2012
# 99.0
# Sao Paulo April 2012
# 82.0
# Sao Paulo May 2012
# 82.0
# Sao Paulo June 2012
# 30.0
# Sao Paulo July 2012
# 179.0
# Sao Paulo August 2012
# 435.0
# Sao Paulo September 2012
# 813.0
# Sao Paulo October 2012
# 206.0
# Sao Paulo November 2012
# 50.0
# Sao Paulo December 2012
# 64.0
# 82.0
# Sao Paulo January 2013
# 36.0
# Sao Paulo Feburary 2013
# 100.0
# Sao Paulo March 2013
# 57.0
# Sao Paulo April 2013
# 103.0
# Sao Paulo May 2013
# 118.0
# Sao Paulo June 2013
# 47.0
# Sao Paulo July 2013
# 181.0
# Sao Paulo August 2013
# 497.0
# Sao Paulo September 2013
# 560.0
# Sao Paulo October 2013
# 127.0
# Sao Paulo November 2013
# 120.0
# Sao Paulo December 2013
# 109.0
# 113.5
# Sao Paulo January 2014
# 99.0
# Sao Paulo Feburary 2014
# 112.0
# Sao Paulo March 2014
# 75.0
# Sao Paulo April 2014
# 103.0
# Sao Paulo May 2014
# 181.0
# Sao Paulo June 2014
# 331.0
# Sao Paulo July 2014
# 476.0
# Sao Paulo August 2014
# 1458.0
# Sao Paulo September 2014
# 882.0
# Sao Paulo October 2014
# 887.0
# Sao Paulo November 2014
# 56.0
# Sao Paulo December 2014
# 57.0
# 146.5
# Sao Paulo January 2015
# 120.0
# Sao Paulo Feburary 2015
# 69.0
# Sao Paulo March 2015
# 68.0
# Sao Paulo April 2015
# 76.0
# Sao Paulo May 2015
# 65.0
# Sao Paulo June 2015
# 147.0
# Sao Paulo July 2015
# 149.0
# Sao Paulo August 2015
# 643.0
# Sao Paulo September 2015
# 368.0
# Sao Paulo October 2015
# 213.0
# Sao Paulo November 2015
# 21.0
# Sao Paulo December 2015
# 45.0
# 98.0
# Sao Paulo January 2016
# 85.0
# Sao Paulo Feburary 2016
# 188.0
# Sao Paulo March 2016
# 82.0
# Sao Paulo April 2016
# 307.0
# Sao Paulo May 2016
# 139.0
# Sao Paulo June 2016
# 197.0
# Sao Paulo July 2016
# 687.0
# Sao Paulo August 2016
# 797.0
# Sao Paulo September 2016
# 490.0
# Sao Paulo October 2016
# 177.0
# Sao Paulo November 2016
# 39.0
# Sao Paulo December 2016
# 47.0
# 182.5
# Sao Paulo January 2017
# 28.0
# Sao Paulo Feburary 2017
# 107.0
# Sao Paulo March 2017
# 103.0
# Sao Paulo April 2017
# 41.0
# Sao Paulo May 2017
# 43.0
# Sao Paulo June 2017
# 217.0
# Sao Paulo July 2017
# 802.0
# Sao Paulo August 2017
# 981.0
# Sao Paulo September 2017
# 2868.0
# Sao Paulo October 2017
# 179.0
# Sao Paulo November 2017
# 37.0
# Sao Paulo December 2017
# 107.0
# [277.5, 449.0, 201.0, 189.5, 240.0, 134.5, 123.0, 187.5, 92.5, 92.5, 56.0, 75.0, 146.5, 111.5, 82.0, 113.5, 146.5, 98.0, 182.5, 107.0]
# Sergipe January 1998
# 0.0
# Sergipe Feburary 1998
# 0.0
# Sergipe March 1998
# 0.0
# Sergipe April 1998
# 0.0
# Sergipe May 1998
# 0.0
# Sergipe June 1998
# 0.0
# Sergipe July 1998
# 0.0
# Sergipe August 1998
# 0.0
# Sergipe September 1998
# 0.0
# Sergipe October 1998
# 0.0
# Sergipe November 1998
# 12.0
# Sergipe December 1998
# 8.0
# 0.0
# Sergipe January 1999
# 36.0
# Sergipe Feburary 1999
# 25.0
# Sergipe March 1999
# 18.0
# Sergipe April 1999
# 6.0
# Sergipe May 1999
# 0.0
# Sergipe June 1999
# 0.0
# Sergipe July 1999
# 0.0
# Sergipe August 1999
# 0.0
# Sergipe September 1999
# 0.0
# Sergipe October 1999
# 0.0
# Sergipe November 1999
# 3.0
# Sergipe December 1999
# 5.0
# 1.5
# Sergipe January 2000
# 1.0
# Sergipe Feburary 2000
# 6.0
# Sergipe March 2000
# 6.0
# Sergipe April 2000
# 1.0
# Sergipe May 2000
# 0.0
# Sergipe June 2000
# 0.0
# Sergipe July 2000
# 0.0
# Sergipe August 2000
# 0.0
# Sergipe September 2000
# 0.0
# Sergipe October 2000
# 3.0
# Sergipe November 2000
# 0.0
# Sergipe December 2000
# 0.0
# 0.0
# Sergipe January 2001
# 2.0
# Sergipe Feburary 2001
# 2.0
# Sergipe March 2001
# 1.0
# Sergipe April 2001
# 0.0
# Sergipe May 2001
# 3.0
# Sergipe June 2001
# 0.0
# Sergipe July 2001
# 0.0
# Sergipe August 2001
# 0.0
# Sergipe September 2001
# 1.0
# Sergipe October 2001
# 5.0
# Sergipe November 2001
# 5.0
# Sergipe December 2001
# 5.0
# 1.5
# Sergipe January 2002
# 1.0
# Sergipe Feburary 2002
# 6.0
# Sergipe March 2002
# 7.0
# Sergipe April 2002
# 12.0
# Sergipe May 2002
# 0.0
# Sergipe June 2002
# 0.0
# Sergipe July 2002
# 0.0
# Sergipe August 2002
# 2.0
# Sergipe September 2002
# 0.0
# Sergipe October 2002
# 20.0
# Sergipe November 2002
# 57.0
# Sergipe December 2002
# 103.0
# 4.0
# Sergipe January 2003
# 198.0
# Sergipe Feburary 2003
# 50.0
# Sergipe March 2003
# 62.0
# Sergipe April 2003
# 48.0
# Sergipe May 2003
# 2.0
# Sergipe June 2003
# 0.0
# Sergipe July 2003
# 0.0
# Sergipe August 2003
# 0.0
# Sergipe September 2003
# 3.0
# Sergipe October 2003
# 2.0
# Sergipe November 2003
# 2.0
# Sergipe December 2003
# 36.0
# 2.5
# Sergipe January 2004
# 16.0
# Sergipe Feburary 2004
# 10.0
# Sergipe March 2004
# 36.0
# Sergipe April 2004
# 13.0
# Sergipe May 2004
# 5.0
# Sergipe June 2004
# 0.0
# Sergipe July 2004
# 0.0
# Sergipe August 2004
# 0.0
# Sergipe September 2004
# 0.0
# Sergipe October 2004
# 3.0
# Sergipe November 2004
# 41.0
# Sergipe December 2004
# 66.0
# 7.5
# Sergipe January 2005
# 80.0
# Sergipe Feburary 2005
# 19.0
# Sergipe March 2005
# 28.0
# Sergipe April 2005
# 8.0
# Sergipe May 2005
# 0.0
# Sergipe June 2005
# 0.0
# Sergipe July 2005
# 0.0
# Sergipe August 2005
# 0.0
# Sergipe September 2005
# 2.0
# Sergipe October 2005
# 11.0
# Sergipe November 2005
# 23.0
# Sergipe December 2005
# 29.0
# 9.5
# Sergipe January 2006
# 36.0
# Sergipe Feburary 2006
# 36.0
# Sergipe March 2006
# 41.0
# Sergipe April 2006
# 9.0
# Sergipe May 2006
# 0.0
# Sergipe June 2006
# 0.0
# Sergipe July 2006
# 0.0
# Sergipe August 2006
# 0.0
# Sergipe September 2006
# 0.0
# Sergipe October 2006
# 3.0
# Sergipe November 2006
# 5.0
# Sergipe December 2006
# 17.0
# 4.0
# Sergipe January 2007
# 56.0
# Sergipe Feburary 2007
# 22.0
# Sergipe March 2007
# 2.0
# Sergipe April 2007
# 1.0
# Sergipe May 2007
# 0.0
# Sergipe June 2007
# 0.0
# Sergipe July 2007
# 0.0
# Sergipe August 2007
# 0.0
# Sergipe September 2007
# 0.0
# Sergipe October 2007
# 3.0
# Sergipe November 2007
# 7.0
# Sergipe December 2007
# 33.0
# 1.5
# Sergipe January 2008
# 100.0
# Sergipe Feburary 2008
# 67.0
# Sergipe March 2008
# 43.0
# Sergipe April 2008
# 2.0
# Sergipe May 2008
# 0.0
# Sergipe June 2008
# 0.0
# Sergipe July 2008
# 0.0
# Sergipe August 2008
# 0.0
# Sergipe September 2008
# 0.0
# Sergipe October 2008
# 0.0
# Sergipe November 2008
# 17.0
# Sergipe December 2008
# 14.0
# 1.0
# Sergipe January 2009
# 60.0
# Sergipe Feburary 2009
# 64.0
# Sergipe March 2009
# 29.0
# Sergipe April 2009
# 19.0
# Sergipe May 2009
# 0.0
# Sergipe June 2009
# 2.0
# Sergipe July 2009
# 0.0
# Sergipe August 2009
# 0.0
# Sergipe September 2009
# 1.0
# Sergipe October 2009
# 1.0
# Sergipe November 2009
# 9.0
# Sergipe December 2009
# 21.0
# 5.5
# Sergipe January 2010
# 29.0
# Sergipe Feburary 2010
# 33.0
# Sergipe March 2010
# 44.0
# Sergipe April 2010
# 1.0
# Sergipe May 2010
# 0.0
# Sergipe June 2010
# 0.0
# Sergipe July 2010
# 0.0
# Sergipe August 2010
# 0.0
# Sergipe September 2010
# 0.0
# Sergipe October 2010
# 1.0
# Sergipe November 2010
# 16.0
# Sergipe December 2010
# 19.0
# 1.0
# Sergipe January 2011
# 36.0
# Sergipe Feburary 2011
# 31.0
# Sergipe March 2011
# 47.0
# Sergipe April 2011
# 12.0
# Sergipe May 2011
# 0.0
# Sergipe June 2011
# 1.0
# Sergipe July 2011
# 0.0
# Sergipe August 2011
# 1.0
# Sergipe September 2011
# 0.0
# Sergipe October 2011
# 5.0
# Sergipe November 2011
# 4.0
# Sergipe December 2011
# 36.0
# 4.5
# Sergipe January 2012
# 39.0
# Sergipe Feburary 2012
# 34.0
# Sergipe March 2012
# 71.0
# Sergipe April 2012
# 40.0
# Sergipe May 2012
# 17.0
# Sergipe June 2012
# 3.0
# Sergipe July 2012
# 1.0
# Sergipe August 2012
# 0.0
# Sergipe September 2012
# 1.0
# Sergipe October 2012
# 1.0
# Sergipe November 2012
# 6.0
# Sergipe December 2012
# 18.0
# 11.5
# Sergipe January 2013
# 34.0
# Sergipe Feburary 2013
# 47.0
# Sergipe March 2013
# 67.0
# Sergipe April 2013
# 15.0
# Sergipe May 2013
# 1.0
# Sergipe June 2013
# 1.0
# Sergipe July 2013
# 0.0
# Sergipe August 2013
# 0.0
# Sergipe September 2013
# 1.0
# Sergipe October 2013
# 3.0
# Sergipe November 2013
# 7.0
# Sergipe December 2013
# 9.0
# 5.0
# Sergipe January 2014
# 20.0
# Sergipe Feburary 2014
# 18.0
# Sergipe March 2014
# 33.0
# Sergipe April 2014
# 7.0
# Sergipe May 2014
# 1.0
# Sergipe June 2014
# 0.0
# Sergipe July 2014
# 0.0
# Sergipe August 2014
# 0.0
# Sergipe September 2014
# 4.0
# Sergipe October 2014
# 3.0
# Sergipe November 2014
# 9.0
# Sergipe December 2014
# 9.0
# 5.5
# Sergipe January 2015
# 44.0
# Sergipe Feburary 2015
# 40.0
# Sergipe March 2015
# 49.0
# Sergipe April 2015
# 35.0
# Sergipe May 2015
# 11.0
# Sergipe June 2015
# 3.0
# Sergipe July 2015
# 0.0
# Sergipe August 2015
# 0.0
# Sergipe September 2015
# 1.0
# Sergipe October 2015
# 6.0
# Sergipe November 2015
# 47.0
# Sergipe December 2015
# 63.0
# 23.0
# Sergipe January 2016
# 9.0
# Sergipe Feburary 2016
# 22.0
# Sergipe March 2016
# 26.0
# Sergipe April 2016
# 14.0
# Sergipe May 2016
# 9.0
# Sergipe June 2016
# 1.0
# Sergipe July 2016
# 0.0
# Sergipe August 2016
# 6.0
# Sergipe September 2016
# 2.0
# Sergipe October 2016
# 10.0
# Sergipe November 2016
# 17.0
# Sergipe December 2016
# 36.0
# 9.5
# Sergipe January 2017
# 31.0
# Sergipe Feburary 2017
# 18.0
# Sergipe March 2017
# 16.0
# Sergipe April 2017
# 8.0
# Sergipe May 2017
# 1.0
# Sergipe June 2017
# 0.0
# Sergipe July 2017
# 0.0
# Sergipe August 2017
# 0.0
# Sergipe September 2017
# 0.0
# Sergipe October 2017
# 0.0
# Sergipe November 2017
# 1.0
# Sergipe December 2017
# 1.0
# [0.0, 1.5, 0.0, 1.5, 4.0, 2.5, 7.5, 9.5, 4.0, 1.5, 1.0, 5.5, 1.0, 4.5, 11.5, 5.0, 5.5, 23.0, 9.5, 1.0]
# Tocantins January 1998
# 0.0
# Tocantins Feburary 1998
# 0.0
# Tocantins March 1998
# 0.0
# Tocantins April 1998
# 0.0
# Tocantins May 1998
# 0.0
# Tocantins June 1998
# 252.0
# Tocantins July 1998
# 640.0
# Tocantins August 1998
# 3747.0
# Tocantins September 1998
# 5149.0
# Tocantins October 1998
# 1738.0
# Tocantins November 1998
# 1.0
# Tocantins December 1998
# 9.0
# 5.0
# Tocantins January 1999
# 36.0
# Tocantins Feburary 1999
# 1.0
# Tocantins March 1999
# 1.0
# Tocantins April 1999
# 9.0
# Tocantins May 1999
# 24.0
# Tocantins June 1999
# 113.0
# Tocantins July 1999
# 373.0
# Tocantins August 1999
# 1284.0
# Tocantins September 1999
# 3415.0
# Tocantins October 1999
# 1378.0
# Tocantins November 1999
# 29.0
# Tocantins December 1999
# 16.0
# 32.5
# Tocantins January 2000
# 15.0
# Tocantins Feburary 2000
# 6.0
# Tocantins March 2000
# 4.0
# Tocantins April 2000
# 0.0
# Tocantins May 2000
# 69.0
# Tocantins June 2000
# 278.0
# Tocantins July 2000
# 500.0
# Tocantins August 2000
# 1949.0
# Tocantins September 2000
# 2552.0
# Tocantins October 2000
# 1053.0
# Tocantins November 2000
# 96.0
# Tocantins December 2000
# 20.0
# 82.5
# Tocantins January 2001
# 19.0
# Tocantins Feburary 2001
# 6.0
# Tocantins March 2001
# 0.0
# Tocantins April 2001
# 19.0
# Tocantins May 2001
# 48.0
# Tocantins June 2001
# 305.0
# Tocantins July 2001
# 830.0
# Tocantins August 2001
# 2242.0
# Tocantins September 2001
# 4839.0
# Tocantins October 2001
# 684.0
# Tocantins November 2001
# 100.0
# Tocantins December 2001
# 21.0
# 74.0
# Tocantins January 2002
# 35.0
# Tocantins Feburary 2002
# 48.0
# Tocantins March 2002
# 33.0
# Tocantins April 2002
# 37.0
# Tocantins May 2002
# 138.0
# Tocantins June 2002
# 396.0
# Tocantins July 2002
# 976.0
# Tocantins August 2002
# 3027.0
# Tocantins September 2002
# 5314.0
# Tocantins October 2002
# 1537.0
# Tocantins November 2002
# 207.0
# Tocantins December 2002
# 39.0
# 172.5
# Tocantins January 2003
# 35.0
# Tocantins Feburary 2003
# 15.0
# Tocantins March 2003
# 19.0
# Tocantins April 2003
# 64.0
# Tocantins May 2003
# 96.0
# Tocantins June 2003
# 329.0
# Tocantins July 2003
# 762.0
# Tocantins August 2003
# 1339.0
# Tocantins September 2003
# 4637.0
# Tocantins October 2003
# 1339.0
# Tocantins November 2003
# 146.0
# Tocantins December 2003
# 109.0
# 127.5
# Tocantins January 2004
# 40.0
# Tocantins Feburary 2004
# 7.0
# Tocantins March 2004
# 23.0
# Tocantins April 2004
# 52.0
# Tocantins May 2004
# 350.0
# Tocantins June 2004
# 1079.0
# Tocantins July 2004
# 1389.0
# Tocantins August 2004
# 1776.0
# Tocantins September 2004
# 5308.0
# Tocantins October 2004
# 1658.0
# Tocantins November 2004
# 424.0
# Tocantins December 2004
# 96.0
# 387.0
# Tocantins January 2005
# 66.0
# Tocantins Feburary 2005
# 27.0
# Tocantins March 2005
# 13.0
# Tocantins April 2005
# 52.0
# Tocantins May 2005
# 236.0
# Tocantins June 2005
# 669.0
# Tocantins July 2005
# 1082.0
# Tocantins August 2005
# 1840.0
# Tocantins September 2005
# 5319.0
# Tocantins October 2005
# 2913.0
# Tocantins November 2005
# 271.0
# Tocantins December 2005
# 53.0
# 253.5
# Tocantins January 2006
# 91.0
# Tocantins Feburary 2006
# 14.0
# Tocantins March 2006
# 11.0
# Tocantins April 2006
# 4.0
# Tocantins May 2006
# 35.0
# Tocantins June 2006
# 289.0
# Tocantins July 2006
# 430.0
# Tocantins August 2006
# 1277.0
# Tocantins September 2006
# 2979.0
# Tocantins October 2006
# 1176.0
# Tocantins November 2006
# 108.0
# Tocantins December 2006
# 15.0
# 99.5
# Tocantins January 2007
# 34.0
# Tocantins Feburary 2007
# 8.0
# Tocantins March 2007
# 99.0
# Tocantins April 2007
# 22.0
# Tocantins May 2007
# 250.0
# Tocantins June 2007
# 591.0
# Tocantins July 2007
# 982.0
# Tocantins August 2007
# 4747.0
# Tocantins September 2007
# 6829.0
# Tocantins October 2007
# 2252.0
# Tocantins November 2007
# 147.0
# Tocantins December 2007
# 13.0
# 198.5
# Tocantins January 2008
# 28.0
# Tocantins Feburary 2008
# 6.0
# Tocantins March 2008
# 4.0
# Tocantins April 2008
# 46.0
# Tocantins May 2008
# 81.0
# Tocantins June 2008
# 282.0
# Tocantins July 2008
# 441.0
# Tocantins August 2008
# 845.0
# Tocantins September 2008
# 2390.0
# Tocantins October 2008
# 2832.0
# Tocantins November 2008
# 104.0
# Tocantins December 2008
# 7.0
# 92.5
# Tocantins January 2009
# 43.0
# Tocantins Feburary 2009
# 21.0
# Tocantins March 2009
# 23.0
# Tocantins April 2009
# 5.0
# Tocantins May 2009
# 91.0
# Tocantins June 2009
# 421.0
# Tocantins July 2009
# 989.0
# Tocantins August 2009
# 1124.0
# Tocantins September 2009
# 2017.0
# Tocantins October 2009
# 718.0
# Tocantins November 2009
# 251.0
# Tocantins December 2009
# 46.0
# 171.0
# Tocantins January 2010
# 79.0
# Tocantins Feburary 2010
# 32.0
# Tocantins March 2010
# 120.0
# Tocantins April 2010
# 419.0
# Tocantins May 2010
# 580.0
# Tocantins June 2010
# 767.0
# Tocantins July 2010
# 2408.0
# Tocantins August 2010
# 7865.0
# Tocantins September 2010
# 10172.0
# Tocantins October 2010
# 2272.0
# Tocantins November 2010
# 283.0
# Tocantins December 2010
# 72.0
# 499.5
# Tocantins January 2011
# 14.0
# Tocantins Feburary 2011
# 13.0
# Tocantins March 2011
# 16.0
# Tocantins April 2011
# 106.0
# Tocantins May 2011
# 354.0
# Tocantins June 2011
# 717.0
# Tocantins July 2011
# 1001.0
# Tocantins August 2011
# 1668.0
# Tocantins September 2011
# 4658.0
# Tocantins October 2011
# 1591.0
# Tocantins November 2011
# 144.0
# Tocantins December 2011
# 105.0
# 249.0
# Tocantins January 2012
# 12.0
# Tocantins Feburary 2012
# 45.0
# Tocantins March 2012
# 80.0
# Tocantins April 2012
# 226.0
# Tocantins May 2012
# 467.0
# Tocantins June 2012
# 922.0
# Tocantins July 2012
# 1693.0
# Tocantins August 2012
# 4280.0
# Tocantins September 2012
# 746.0
# Tocantins October 2012
# 3680.0
# Tocantins November 2012
# 179.0
# Tocantins December 2012
# 128.0
# 346.5
# Tocantins January 2013
# 50.0
# Tocantins Feburary 2013
# 37.0
# Tocantins March 2013
# 60.0
# Tocantins April 2013
# 130.0
# Tocantins May 2013
# 373.0
# Tocantins June 2013
# 873.0
# Tocantins July 2013
# 1393.0
# Tocantins August 2013
# 1810.0
# Tocantins September 2013
# 2445.0
# Tocantins October 2013
# 2155.0
# Tocantins November 2013
# 345.0
# Tocantins December 2013
# 85.0
# 359.0
# Tocantins January 2014
# 89.0
# Tocantins Feburary 2014
# 73.0
# Tocantins March 2014
# 58.0
# Tocantins April 2014
# 187.0
# Tocantins May 2014
# 618.0
# Tocantins June 2014
# 1372.0
# Tocantins July 2014
# 1404.0
# Tocantins August 2014
# 2917.0
# Tocantins September 2014
# 3520.0
# Tocantins October 2014
# 4.0
# Tocantins November 2014
# 451.0
# Tocantins December 2014
# 223.0
# 337.0
# Tocantins January 2015
# 186.0
# Tocantins Feburary 2015
# 65.0
# Tocantins March 2015
# 85.0
# Tocantins April 2015
# 88.0
# Tocantins May 2015
# 512.0
# Tocantins June 2015
# 1150.0
# Tocantins July 2015
# 1217.0
# Tocantins August 2015
# 2540.0
# Tocantins September 2015
# 5510.0
# Tocantins October 2015
# 4844.0
# Tocantins November 2015
# 833.0
# Tocantins December 2015
# 373.0
# 672.5
# Tocantins January 2016
# 42.0
# Tocantins Feburary 2016
# 383.0
# Tocantins March 2016
# 165.0
# Tocantins April 2016
# 369.0
# Tocantins May 2016
# 778.0
# Tocantins June 2016
# 1148.0
# Tocantins July 2016
# 2737.0
# Tocantins August 2016
# 3213.0
# Tocantins September 2016
# 3245.0
# Tocantins October 2016
# 2032.0
# Tocantins November 2016
# 623.0
# Tocantins December 2016
# 119.0
# 700.5
# Tocantins January 2017
# 61.0
# Tocantins Feburary 2017
# 25.0
# Tocantins March 2017
# 98.0
# Tocantins April 2017
# 164.0
# Tocantins May 2017
# 576.0
# Tocantins June 2017
# 1320.0
# Tocantins July 2017
# 2397.0
# Tocantins August 2017
# 3536.0
# Tocantins September 2017
# 10737.0
# Tocantins October 2017
# 2969.0
# Tocantins November 2017
# 434.0
# Tocantins December 2017
# 576.0
# [5.0, 32.5, 82.5, 74.0, 172.5, 127.5, 387.0, 253.5, 99.5, 198.5, 92.5, 171.0, 499.5, 249.0, 346.5, 359.0, 337.0, 672.5, 700.5, 576.0]
# [1.5, 0.0, 1.0, 0.5, 1.0, 8.0, 7.0, 13.0, 6.0, 4.5, 0.0, 2.5, 6.0, 7.0, 5.0, 13.5, 12.0, 24.0, 33.5, 45.0]

# %%
# Your code here

# %%
#Given Test
assert median_num_fires_monthly_yearly['Acre'] == \
[1.5, 0.0, 1.0, 0.5, 1.0, 8.0, 7.0, 13.0, 6.0, 4.5, 0.0, 2.5, 6.0, 7.0, 5.0, 13.5, 12.0, 24.0, 33.5, 45.0] \
, "something is wrong here"

# %%
#DONT CHANGE THIS. WE USE IT TO MAKE THE OUTPUT LEGIBLE FOR GRADING
import pprint
pp = pprint.PrettyPrinter(indent=1)
pp.pprint(median_num_fires_monthly_yearly)
# Out:
# {'Acre': [1.5,
#           0.0,
#           1.0,
#           0.5,
#           1.0,
#           8.0,
#           7.0,
#           13.0,
#           6.0,
#           4.5,
#           0.0,
#           2.5,
#           6.0,
#           7.0,
#           5.0,
#           13.5,
#           12.0,
#           24.0,
#           33.5,
#           45.0],
#  'Alagoas': [0.0,
#              4.0,
#              7.5,
#              3.0,
#              13.0,
#              12.5,
#              6.5,
#              11.5,
#              8.0,
#              4.5,
#              18.0,
#              21.5,
#              10.5,
#              20.0,
#              24.5,
#              14.5,
#              12.5,
#              36.0,
#              13.5,
#              7.0],
#  'Amapa': [0.0,
#            1.5,
#            1.0,
#            0.5,
#            5.0,
#            8.0,
#            7.0,
#            3.0,
#            4.0,
#            0.0,
#            2.0,
#            4.0,
#            2.0,
#            4.0,
#            13.0,
#            2.5,
#            7.0,
#            9.5,
#            12.0,
#            3.0],
#  'Amazonas': [4.0,
#               9.0,
#               55.5,
#               8.5,
#               30.5,
#               152.5,
#               107.5,
#               61.0,
#               21.5,
#               63.5,
#               24.0,
#               57.5,
#               119.5,
#               87.0,
#               62.5,
#               138.0,
#               138.0,
#               231.5,
#               433.0,
#               119.0],
#  'Bahia': [52.0,
#            95.0,
#            92.5,
#            129.5,
#            376.5,
#            407.5,
#            299.5,
#            240.0,
#            227.0,
#            321.5,
#            253.0,
#            278.5,
#            261.5,
#            209.5,
#            400.0,
#            259.5,
#            233.5,
#            281.0,
#            376.5,
#            174.0],
#  'Ceara': [38.5,
#            65.0,
#            17.0,
#            113.5,
#            54.0,
#            61.5,
#            22.5,
#            38.0,
#            36.5,
#            96.5,
#            22.0,
#            17.0,
#            132.5,
#            25.0,
#            161.5,
#            40.5,
#            81.0,
#            76.0,
#            112.0,
#            26.0],
#  'Distrito Federal': [0.0,
#                       1.5,
#                       0.5,
#                       0.5,
#                       1.0,
#                       0.5,
#                       3.5,
#                       2.0,
#                       0.5,
#                       2.5,
#                       3.0,
#                       2.0,
#                       7.0,
#                       1.5,
#                       2.0,
#                       2.0,
#                       4.0,
#                       1.5,
#                       7.0,
#                       6.0],
#  'Espirito Santo': [4.5,
#                     9.5,
#                     5.0,
#                     6.5,
#                     10.5,
#                     24.5,
#                     4.5,
#                     5.0,
#                     10.5,
#                     11.0,
#                     6.5,
#                     12.5,
#                     8.5,
#                     6.5,
#                     22.5,
#                     15.5,
#                     17.5,
#                     47.5,
#                     48.5,
#                     10.0],
#  'Goias': [30.0,
#            180.0,
#            42.0,
#            67.0,
#            181.5,
#            148.5,
#            224.0,
#            154.0,
#            77.5,
#            86.5,
#            48.0,
#            96.5,
#            172.0,
#            103.5,
#            98.0,
#            166.5,
#            195.5,
#            228.0,
#            200.0,
#            135.0],
#  'Maranhao': [176.0,
#               156.0,
#               163.5,
#               324.5,
#               750.5,
#               769.5,
#               1036.0,
#               840.5,
#               366.5,
#               657.5,
#               368.5,
#               259.5,
#               1148.5,
#               813.0,
#               620.5,
#               804.5,
#               1440.0,
#               1264.5,
#               1143.0,
#               885.0],
#  'Mato Grosso': [129.0,
#                  786.5,
#                  848.0,
#                  783.0,
#                  2716.5,
#                  1859.5,
#                  2409.0,
#                  1504.5,
#                  901.5,
#                  476.0,
#                  259.5,
#                  557.5,
#                  935.5,
#                  760.5,
#                  666.5,
#                  901.5,
#                  975.5,
#                  1181.0,
#                  1251.0,
#                  845.0],
#  'Minas Gerais': [26.5,
#                   122.0,
#                   58.0,
#                   72.5,
#                   216.0,
#                   235.0,
#                   167.0,
#                   134.0,
#                   84.5,
#                   169.5,
#                   99.0,
#                   150.5,
#                   147.0,
#                   152.0,
#                   204.0,
#                   147.0,
#                   224.0,
#                   244.0,
#                   207.0,
#                   136.0],
#  'Para': [638.0,
#           766.0,
#           303.5,
#           375.0,
#           460.5,
#           1235.5,
#           4436.0,
#           1631.5,
#           509.0,
#           471.5,
#           407.5,
#           319.0,
#           934.5,
#           370.0,
#           526.5,
#           173.0,
#           572.0,
#           815.5,
#           1450.5,
#           679.0],
#  'Paraiba': [1.5,
#              3.5,
#              6.0,
#              9.5,
#              13.0,
#              10.0,
#              10.5,
#              13.0,
#              5.5,
#              7.5,
#              14.0,
#              6.5,
#              15.5,
#              8.5,
#              14.0,
#              7.5,
#              24.0,
#              13.0,
#              13.0,
#              3.0],
#  'Pernambuco': [3.0,
#                 14.5,
#                 10.5,
#                 6.5,
#                 21.5,
#                 30.5,
#                 21.0,
#                 39.0,
#                 29.5,
#                 20.5,
#                 40.0,
#                 21.5,
#                 40.0,
#                 33.0,
#                 55.0,
#                 34.5,
#                 30.5,
#                 44.0,
#                 21.5,
#                 20.0],
#  'Piau': [82.5,
#           60.5,
#           50.0,
#           158.5,
#           267.0,
#           247.5,
#           401.5,
#           308.0,
#           141.5,
#           310.0,
#           79.0,
#           190.5,
#           294.0,
#           412.0,
#           390.5,
#           312.0,
#           359.5,
#           454.5,
#           263.5,
#           193.0],
#  'Rio': [2.0,
#          7.5,
#          3.5,
#          4.0,
#          9.5,
#          12.0,
#          14.0,
#          11.5,
#          10.0,
#          8.0,
#          3.0,
#          22.5,
#          18.0,
#          26.5,
#          18.0,
#          16.5,
#          46.0,
#          34.5,
#          30.0,
#          43.0],
#  'Rondonia': [14.5,
#               9.0,
#               13.0,
#               18.0,
#               116.0,
#               144.0,
#               179.5,
#               126.0,
#               28.5,
#               43.0,
#               9.5,
#               15.0,
#               101.0,
#               92.0,
#               41.0,
#               65.5,
#               118.0,
#               200.5,
#               159.0,
#               192.0],
#  'Roraima': [0.0,
#              12.5,
#              15.0,
#              44.5,
#              90.5,
#              20.5,
#              94.0,
#              71.5,
#              55.0,
#              12.0,
#              28.0,
#              135.0,
#              22.5,
#              78.0,
#              72.5,
#              62.5,
#              105.0,
#              172.0,
#              86.0,
#              51.0],
#  'Santa Catarina': [0.0,
#                     9.0,
#                     20.0,
#                     8.0,
#                     32.0,
#                     102.0,
#                     83.5,
#                     74.0,
#                     43.0,
#                     15.5,
#                     29.0,
#                     33.0,
#                     21.0,
#                     25.0,
#                     42.0,
#                     60.5,
#                     44.0,
#                     34.5,
#                     54.5,
#                     51.0],
#  'Sao Paulo': [277.5,
#                449.0,
#                201.0,
#                189.5,
#                240.0,
#                134.5,
#                123.0,
#                187.5,
#                92.5,
#                92.5,
#                56.0,
#                75.0,
#                146.5,
#                111.5,
#                82.0,
#                113.5,
#                146.5,
#                98.0,
#                182.5,
#                107.0],
#  'Sergipe': [0.0,
#              1.5,
#              0.0,
#              1.5,
#              4.0,
#              2.5,
#              7.5,
#              9.5,
#              4.0,
#              1.5,
#              1.0,
#              5.5,
#              1.0,
#              4.5,
#              11.5,
#              5.0,
#              5.5,
#              23.0,
#              9.5,
#              1.0],
#  'Tocantins': [5.0,
#                32.5,
#                82.5,
#                74.0,
#                172.5,
#                127.5,
#                387.0,
#                253.5,
#                99.5,
#                198.5,
#                92.5,
#                171.0,
#                499.5,
#                249.0,
#                346.5,
#                359.0,
#                337.0,
#                672.5,
#                700.5,
#                576.0]}

# %% [markdown]
# **Part C:** Since we cannot rely on the central limit thereom for the median, we'll bootstrap some samples. Bootstrap 1000 samples for each state. Each bootstrapped sample should have 50 values drawn from the original sample.
#
# Find the median of each bootstrapped sample, and add it to a list. Save the list of median values for the states of **Sao Paulo** and **Goias**. We'll use them later to plot in part D. Then determine the 95% confidence interval of the true median from each list of bootstrapped medians for each state. Add a list of the low and high values of the confidence interval to the given python dictionary below. To help you check your work, the confidence interval of the state of Acre should be from roughly 4 to 7. Your values will change though, because each bootstrapped sample is picked randomly from the original.
#
# For Example:
#
# If the 95% confidence interval on the median is from 6 to 22 for the state of "test", then the dictionary would look like:
#
# {
#
#     "test": [6, 22]
#
# }

# %%
#GIVEN CODE
median_num_fires_bootstrap = {
    'Acre': None,
    'Alagoas': None,
    'Amapa': None,
    'Amazonas': None,
    'Bahia': None,
    'Ceara': None,
    'Distrito Federal': None,
    'Espirito Santo': None,
    'Goias': None,
    'Maranhao': None,
    'Mato Grosso': None,
    'Minas Gerais': None,
    'Para': None,
    'Paraiba': None,
    'Pernambuco': None,
    'Piau': None,
    'Rio': None,
    'Rondonia': None,
    'Roraima': None,
    'Santa Catarina': None,
    'Sao Paulo': None,
    'Sergipe': None,
    'Tocantins': None  
}

# %%
#Your code here.
medians = []
tmp=[]
s= []
g= []

    
for state in state_list:
    medians = []
    for x in range(0,1000):
        tmp = median_num_fires_monthly_yearly[state]
        resample = np.random.choice(tmp,50,replace = True)
        resample_median = np.median(resample)
        medians.append(resample_median)
        if state == 'Sao Paulo':
            s.append(resample_median)
        if state == "Goias":
            g.append(resample_median)
    interval = [np.percentile(medians,5),np.percentile(medians,95)]
    median_num_fires_bootstrap[state]= interval

# %%
#DONT CHANGE THIS. WE USE IT TO MAKE THE OUTPUT LEGIBLE FOR GRADING
import pprint
pp = pprint.PrettyPrinter(indent=1)
pp.pprint(median_num_fires_bootstrap)
# Out:
# {'Acre': [4.75, 7.0],
#  'Alagoas': [8.0, 13.0],
#  'Amapa': [2.5, 4.0],
#  'Amazonas': [58.2125, 107.5],
#  'Bahia': [233.5, 278.5],
#  'Ceara': [38.2375, 65.0],
#  'Distrito Federal': [1.5, 2.0],
#  'Espirito Santo': [8.5, 11.0],
#  'Goias': [98.0, 166.5],
#  'Maranhao': [620.5, 808.75],
#  'Mato Grosso': [786.5, 935.5],
#  'Minas Gerais': [136.0, 167.0],
#  'Para': [471.5, 679.0],
#  'Paraiba': [8.0, 13.0],
#  'Pernambuco': [21.5, 30.5],
#  'Piau': [193.0, 308.0],
#  'Rio': [10.75, 18.0],
#  'Rondonia': [41.0, 116.0],
#  'Roraima': [44.5, 72.5],
#  'Santa Catarina': [29.0, 43.0],
#  'Sao Paulo': [111.5, 146.5],
#  'Sergipe': [1.9750000000000014, 5.0],
#  'Tocantins': [171.0, 337.0]}

# %% [markdown]
# **Part D:** Plot a histogram of the frequency of different median values for the two states **Sao Paulo** and **Goias**. Overlay these histograms on the same plot. Include axis labels, a title, a legend, etc. Choose two colors that work well together and provide enough contrast (e.g. No one can see gold overlayed with yellow), and use reasonable values of the **alpha** parameter so you can see both histograms. Plot two vertical lines that represent the outer bounds of the 95% confidence interval on the true median for each state, in the same color as the state. Does the data for the median look normally distributed? Why or why not? Does this validate our decision to not use the central limit theorem and instead bootstrap our median samples? Explain in a markdown cell below.

# %%
#Your code here.
sao = median_num_fires_bootstrap["Sao Paulo"]
sleft = sao[0]
sright = sao[1]

gio = median_num_fires_bootstrap["Goias"]
gleft= gio[0]
gright = gio[1]

plt.hist(s,label = 'Sao Paulo', color = 'coral',alpha=0.3)
plt.hist(g,label = 'Goias', color = 'seagreen',alpha=0.3)
plt.axvline(sleft,color = 'coral')
plt.axvline(sright,color = 'coral')
plt.axvline(gleft,color = 'seagreen')
plt.axvline(gright,color = 'seagreen')
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# <br>
#
# ---
# <a id='p2'></a>
# [Back to top](#top)
#
# ### [40 points] Problem 2:  Sharknado Prediction
#
# Governor Hickenlooper has charged you with the task of assessing the factors associated with sharknado risk in Colorado. As everyone knows, sharknadoes are a leading cause of sharknado-related illness, and you are a world-renowned data/shark scientist.
#
# You decide to use multiple linear regression to understand and predict what factors lead to increased sharknado hazard. Your lead scientist, aptly named Fin, has collected lots of relevant data at a local sharknado hotspot, the Boulder Reservoir[\*](#footnote). The data cover a variety of sharknado-related environmental and other conditions, and you'll find this data in the file `sharknadoes.csv`.
#
# **Response**:
#
# - $\texttt{sharknado hazard}$: the hazard of a sharknado, where 1 is very unlikely and 100 is highly likely
#
# **Features**:
#
# - $\texttt{taunts}$: the number of times over the past year that someone has taunted a shark
# - $\texttt{clouds}$: what percentage of the sky was covered by clouds (fraction, 0-1)
# - $\texttt{precipitation}$: amount of precipitation in the past 72 hours (inches)
# - $\texttt{earthquake}$: the intensity of the most recent earthquake measured in the continental United States
# - $\texttt{shark attacks}$: the number of shark attacks within 72 hours prior to the observation
# - $\texttt{ice cream sold}$: the number of units of ice cream sold at the beach concession stand
# - $\texttt{misery index}$: an economic indicator for how miserable the average United States citizen is, based on the unemployment rate and the inflation rate. More [here](https://www.stuffyoushouldknow.com/podcasts/whats-the-misery-index.htm) and [here](https://en.wikipedia.org/wiki/Misery_index_(economics)). Higher values correspond to more miserable citizens.
# - $\texttt{temperature}$: the outside temperature, measured in degrees Fahrenheit
# - $\texttt{humidity}$: relative humidity (percent, 0-100)
# - $\texttt{pizzas sold}$: the number of pizzas sold at the beach concession stand in the past year
# - $\texttt{pressure}$: local air pressure (millibar)
# - $\texttt{octopuses}$: the number of octupuses in the vicinity on the day of the observation
# - $\texttt{Zach's shoe size}$: the size of the shoes Zach was wearing when the observation was made
# - $\texttt{Rachel's shoe size}$: the size of the shoes Rachel was wearing when the observation was made

# %% [markdown]
# **Part A**: Read the data from `sharknadoes.csv` into a Pandas DataFrame.  Note that since we will be doing a multiple linear regression we will need all of the features. To make sure the data is "clean", drop any row in the DataFrame that is missing data.

# %%
#Your code here.
sharkDF = pd.read_csv('sharknadoes.csv')
sharkDF = sharkDF.dropna()
sharkDF.head()
# Out:
#    clouds  earthquake  pizzas sold  taunts  pressure  shark attacks  \
# 0    1.00         7.1       5560.0    15.0    847.12            2.0
# 1    1.00         7.4       5179.0    20.0    844.34            4.0
# 2    1.00         7.0       5227.0     0.0    839.48            9.0
# 3    0.13         7.9       5226.0    34.0    851.28            2.0
# 4    1.00         7.5       5491.0     6.0    852.67            2.0
#
#    octopuses  precipitation  misery index  ice cream sold  humidity  \
# 0        7.0       0.824059     12.987180           273.0     86.41
# 1        5.0       0.993296     16.765435           184.0     96.67
# 2        2.0       1.173342     16.494518           141.0     53.85
# 3        6.0       0.919291      8.277176           146.0     88.72
# 4        4.0       1.729127      5.904750           178.0     63.08
#
#    temperature  Zachs shoe size  Rachels shoe size  sharknado hazard
# 0         78.0             42.0                9.0             40.22
# 1         89.0             42.0                9.5             36.42
# 2         65.0              9.5                9.0             19.54
# 3         36.0              9.5               10.0             85.00
# 4         72.0             42.0                9.0             56.34

# %% [markdown]
# **Part B**: Perform the appropriate statistical test at the $\alpha = 0.025$ significance level to determine if _at least one_ of the features is related to the the response $y$.  Clearly describe your methodology and show all computations in Python.

# %%
#Your code here.
# Extract response vector y and feature matrix X from DataFrame
y, X = sharkDF["sharknado hazard"], sharkDF.iloc[:,:-1]


# Add constant to X 
X = sm.add_constant(X)

# Fit OLS model 
model = sm.OLS(y, X).fit() 

# Print model summary 
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       sharknado hazard   R-squared:                       0.978
# Model:                            OLS   Adj. R-squared:                  0.972
# Method:                 Least Squares   F-statistic:                     179.4
# Date:                Wed, 11 Dec 2019   Prob (F-statistic):           9.60e-42
# Time:                        21:41:13   Log-Likelihood:                -174.23
# No. Observations:                  72   AIC:                             378.5
# Df Residuals:                      57   BIC:                             412.6
# Df Model:                          14
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const             -2549.8985     67.605    -37.718      0.000   -2685.275   -2414.522
# clouds               -1.5106      2.566     -0.589      0.558      -6.650       3.628
# earthquake            2.5079      0.467      5.367      0.000       1.572       3.444
# pizzas sold          -0.0006      0.002     -0.373      0.711      -0.004       0.003
# taunts                0.3117      0.042      7.447      0.000       0.228       0.396
# pressure              3.0688      0.079     38.850      0.000       2.911       3.227
# shark attacks        -0.1151      0.144     -0.797      0.429      -0.404       0.174
# octopuses            -0.0749      0.143     -0.524      0.602      -0.361       0.211
# precipitation         1.3982      0.930      1.503      0.138      -0.464       3.261
# misery index          0.0273      0.080      0.340      0.735      -0.133       0.188
# ice cream sold        0.0096      0.008      1.193      0.238      -0.007       0.026
# humidity              0.0188      0.027      0.706      0.483      -0.035       0.072
# temperature          -0.4426      0.053     -8.396      0.000      -0.548      -0.337
# Zachs shoe size       0.0271      0.023      1.175      0.245      -0.019       0.073
# Rachels shoe size     0.2814      1.273      0.221      0.826      -2.268       2.831
# ==============================================================================
# Omnibus:                        0.821   Durbin-Watson:                   2.225
# Prob(Omnibus):                  0.663   Jarque-Bera (JB):                0.300
# Skew:                           0.005   Prob(JB):                        0.861
# Kurtosis:                       3.316   Cond. No.                     1.03e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.03e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# **Part C**: Write a function `backward_select(df, resp_str, maxsse)` that takes in the DataFrame (`df`), the name of the column corresponding to the response (`resp_str`), and the maximum desired sum of squared errors (`maxsse`), and returns a list of feature names corresponding to the most important features via backward selection.  Use your code to determine the reduced MLR model with the minimal number of features such that the SSE of the reduced model is less than 570. At each stage in backward selection you should remove the feature that has the highest p-value associated with the hypothesis test for the given slope coefficient $\beta_k \neq 0$.
#
# Your code should clearly indicate which feature was removed in each stage, and the SSE associated with the model fit before the feature's removal. _Specifically, please write your code to print the name of the feature that is going to be removed and the SSE before its removal_. Afterward, be sure to report all of the retained features and the SSE of the reduced model.
#
# **Note**: The point of this exercise is to see if you can implement **backward_select** yourself.  You may of course use canned routines like statmodels OLS, but you may not call any Python method that explicitly performs backward selection.

# %%
def backward_select(df, resp_str, maxsse):
    #Your code here.
    x = sharkDF.iloc[:,:-1]
    x = sm.add_constant(x)
    y = df[resp_str]
    model = sm.OLS(y, x).fit()
    y_hat = y
    prediction = model.predict(x)
    k = (y - prediction)**2
    sse = np.sum(k)
    
    while(sse < maxsse):
        oldSSE = sse
        p = model.pvalues
        removelow = p.idxmax()
        tmp = x.copy()
        x = tmp.drop(columns =removelow)
        x = sm.add_constant(x)
        model = sm.OLS(y, x).fit()
        y_hat = y
        prediction = model.predict(x)
        k = (y - prediction)**2
        sse = np.sum(k)
        if sse < maxsse:
            print("dropping",removelow,"previous sse befoe drop ",oldSSE)
        else:
            # we dropped the column when we shoudlnt have 
            x = tmp
    x = x.drop(columns = 'const')
    print("Features remaining: ",list(x.columns))
    
    return x
    
    
features_left = backward_select(sharkDF,"sharknado hazard", 570)
# Out:
# dropping Rachels shoe size previous sse befoe drop  532.9436707404283
# dropping misery index previous sse befoe drop  533.4003410558921
# dropping octopuses previous sse befoe drop  534.6875698945835
# dropping clouds previous sse befoe drop  536.5069911256901
# dropping pizzas sold previous sse befoe drop  539.49656163576
# dropping humidity previous sse befoe drop  543.357200472107
# dropping shark attacks previous sse befoe drop  547.4141982866556
# dropping Zachs shoe size previous sse befoe drop  552.1548653819143
# Features remaining:  ['earthquake', 'taunts', 'pressure', 'precipitation', 'ice cream sold', 'temperature']

# %% [markdown]
# **Part D**: Write down the final multiple linear regression model, including estimated parameters, obtained by your backward selection process.

# %%
#Your code here.
y, X = sharkDF["sharknado hazard"], sharkDF[features_left.columns.values]
X = sm.add_constant(X)

model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       sharknado hazard   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     450.3
# Date:                Wed, 11 Dec 2019   Prob (F-statistic):           6.28e-51
# Time:                        23:05:19   Log-Likelihood:                -176.27
# No. Observations:                  72   AIC:                             366.5
# Df Residuals:                      65   BIC:                             382.5
# Df Model:                           6
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const          -2542.0392     59.776    -42.526      0.000   -2661.420   -2422.659
# earthquake         2.4012      0.435      5.520      0.000       1.532       3.270
# taunts             0.3188      0.037      8.534      0.000       0.244       0.393
# pressure           3.0618      0.071     42.836      0.000       2.919       3.205
# precipitation      1.2559      0.885      1.419      0.161      -0.512       3.023
# ice cream sold     0.0099      0.008      1.311      0.194      -0.005       0.025
# temperature       -0.4680      0.033    -14.220      0.000      -0.534      -0.402
# ==============================================================================
# Omnibus:                        1.389   Durbin-Watson:                   2.233
# Prob(Omnibus):                  0.499   Jarque-Bera (JB):                0.798
# Skew:                           0.210   Prob(JB):                        0.671
# Kurtosis:                       3.300   Cond. No.                     1.50e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# $\hat{y} = -2542.0392 +2.4012 * earthquake + 0.3188 * taunts + 3.0618*pressure + 1.2559*precip +0.0099*ice cream -0.4680 * temp $

# %% [markdown]
# **Part E**: Perform the appropriate statistical test at the $\alpha = 0.025$ significance level to determine whether there is a statistically significant difference between the full model with all features and the reduced model obtained by backward selection in **Part D**. You may use output from your model fit above, but all calculations should be set up in Markdown/MathJax.

# %% [markdown]
# **Part F**: Based on your conclusions in **Part E**, use the _better_ of the two models to predict the sharknado hazard when the following features are observed:
#
# - $\texttt{taunts}$: 47
# - $\texttt{clouds}$: 0.8
# - $\texttt{precipitation}$: 1 inch
# - $\texttt{earthquake}$: 5
# - $\texttt{shark attacks}$: 11
# - $\texttt{ice cream sold}$: 120
# - $\texttt{misery index}$: 15
# - $\texttt{temperature}$: 70 degrees F
# - $\texttt{humidity}$: 83
# - $\texttt{pizzas sold}$: 5500
# - $\texttt{pressure}$: 850 millibar
# - $\texttt{octopuses}$: 6
# - $\texttt{Zach's shoe size}$: 9.5
# - $\texttt{Rachel's shoe size}$: 9

# %%
#Your code here.

# %% [markdown]
# **Part G:** Consider the model you used in Part E, and consider the fact that you are trying to predict **sharknado hazard**. What is one critical drawback to the MLR model (or any MLR model) for predicting shardnado hazard? What are some modifications that could improve on this issue?

# %% [markdown]
# Features can be correlated based on other features, not only on the response. We should idealy check each feature vs eachother to try and ensure they are not correlated
